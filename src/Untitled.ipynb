# %%
## Part 3 - Extract / Transform

TODO describe your process for extracting, transforming, cleaning your incoming data:

* what columns you'll be using (extracting) from your dataset

* how you're planning to convert the data into analogous python types /
  how you'll deal with type issues 

    (for example, you may want a column that's numeric, but the data contains a label, such as 4 months) 
* any other kind of cleaning (_normalizing_ data, filling in missing values, etc.) that you'll have to perform
* what you'll use a generator for...

# %%
import csv
data = open('Sidewalk_Caf__Licenses_and_Applications.csv')
data = data.read()
data =data[0]

# %%
final_data
# Out:
# [['2010340-DCA',
#   'Inactive',
#   'ELLA HOSPITALITY LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   163,
#   4,
#   16,
#   '12/15/2020'],
#  ['2090170-DCA',
#   'Active',
#   'HOST 213 LLC',
#   'NEW YORK',
#   'Unenclosed',
#   262,
#   11,
#   22,
#   '12/15/2021'],
#  ['2085253-DCA',
#   'Active',
#   'AELE LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   508,
#   12,
#   36,
#   '09/15/2021'],
#  ['1248301-DCA',
#   'Active',
#   'PONENTE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   249,
#   10,
#   20,
#   '04/15/2021'],
#  ['1459574-DCA',
#   'Inactive',
#   'NOISETTE CAFE INC.',
#   'ASTORIA',
#   'Unenclosed',
#   212,
#   11,
#   27,
#   '04/11/2020'],
#  ['0882869-DCA',
#   'Inactive',
#   'LIRA OF NEW YORK, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   98,
#   4,
#   8,
#   '06/03/2020'],
#  ['2085588-DCA',
#   'Active',
#   'DAIMYO GROUP LLC',
#   'NEW YORK',
#   'Unenclosed',
#   141,
#   4,
#   8,
#   '12/15/2021'],
#  ['2023071-DCA',
#   'Active',
#   'SLAMMERS INC',
#   'NEW YORK',
#   'Unenclosed',
#   50,
#   9,
#   18,
#   '04/15/2021'],
#  ['2077329-DCA',
#   'Inactive',
#   'DANICA LLC',
#   'NEW YORK',
#   'Unenclosed',
#   178,
#   10,
#   20,
#   '09/15/2020'],
#  ['1323228-DCA',
#   'Inactive',
#   '112 RESTAURANT CORP.',
#   'BROOKLYN',
#   'Unenclosed',
#   153,
#   6,
#   12,
#   '07/17/2020'],
#  ['2072716-DCA',
#   'Inactive',
#   'PILAR CUBAN RESTAURANT INC',
#   'BROOKLYN',
#   'Unenclosed',
#   180,
#   7,
#   14,
#   '09/15/2020'],
#  ['2044212-DCA',
#   'Inactive',
#   'UNION FRANKLIN ONE INC',
#   'BROOKLYN',
#   'Unenclosed',
#   356,
#   13,
#   30,
#   '12/15/2020'],
#  ['1426863-DCA',
#   'Inactive',
#   'MOLLY PICON LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   124,
#   3,
#   12,
#   '09/15/2020'],
#  ['1221041-DCA',
#   'Inactive',
#   'LEAHLALA, LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   351,
#   8,
#   32,
#   '06/29/2020'],
#  ['2004070-DCA',
#   'Inactive',
#   'UPRIGHT HOLDINGS 547 LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   120,
#   6,
#   12,
#   '12/15/2020'],
#  ['2070023-DCA',
#   'Inactive',
#   'KILO ASTORIA INC',
#   'ASTORIA',
#   'Unenclosed',
#   160,
#   5,
#   20,
#   '09/15/2020'],
#  ['1251800-DCA',
#   'Inactive',
#   'PQ CHELSEA, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   198,
#   8,
#   16,
#   '12/15/2020'],
#  ['1419380-DCA',
#   'Inactive',
#   'ANEJO, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   335,
#   20,
#   40,
#   '12/15/2020'],
#  ['2019393-DCA',
#   'Inactive',
#   '10 DOWNING RESTAURANT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   410,
#   28,
#   59,
#   '02/01/2020'],
#  ['1277362-DCA',
#   'Inactive',
#   'SENGUPTA FOOD SERVICES LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   255,
#   7,
#   14,
#   '12/15/2020'],
#  ['1431733-DCA',
#   'Inactive',
#   'DESSYN BAKERY CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   83,
#   5,
#   10,
#   '09/15/2020'],
#  ['1219900-DCA',
#   'Inactive',
#   'M AND G TOGETHER 4 EVER, LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   390,
#   20,
#   42,
#   '12/15/2020'],
#  ['1298434-DCA',
#   'Active',
#   'SUSHI VIDA INC.',
#   'NEW YORK',
#   'Unenclosed',
#   134,
#   12,
#   32,
#   '12/15/2021'],
#  ['2074660-DCA',
#   'Inactive',
#   'KUBBEH LLC',
#   'NEW YORK',
#   'Unenclosed',
#   151,
#   8,
#   16,
#   '12/15/2020'],
#  ['2052352-DCA',
#   'Inactive',
#   'WILD LIVING, LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   236,
#   12,
#   24,
#   '07/23/2020'],
#  ['1192051-DCA',
#   'Inactive',
#   'EAST PUB INC',
#   'NEW YORK',
#   'Enclosed',
#   808,
#   24,
#   96,
#   '08/31/2020'],
#  ['1164852-DCA',
#   'Inactive',
#   'MULBERRY STREET BAR LLC',
#   'NEW YORK',
#   'Unenclosed',
#   199,
#   4,
#   16,
#   '12/15/2020'],
#  ['1101272-DCA',
#   'Inactive',
#   '659 REST. INC.',
#   'NEW YORK',
#   'Unenclosed',
#   126,
#   4,
#   8,
#   '07/20/2020'],
#  ['2095010-DCA',
#   'Inactive',
#   'CPW REST CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   183,
#   8,
#   16,
#   '04/01/2020'],
#  ['1249286-DCA',
#   'Inactive',
#   '27-39 EAST 30 REST CORP',
#   'NEW YORK',
#   'Unenclosed',
#   176,
#   9,
#   18,
#   '09/13/2020'],
#  ['1387587-DCA',
#   'Active',
#   '357 HOSPITALITY INC.',
#   'NEW YORK',
#   'Unenclosed',
#   473,
#   17,
#   34,
#   '04/15/2021'],
#  ['2053879-DCA',
#   'Inactive',
#   '210 EMPIRE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   793,
#   40,
#   80,
#   '12/18/2019'],
#  ['1137714-DCA',
#   'Inactive',
#   "FIORELLO'S ROMAN CAFE, INC.",
#   'NEW YORK',
#   'Unenclosed',
#   575,
#   32,
#   64,
#   '12/15/2020'],
#  ['1101999-DCA',
#   'Active',
#   'RDK RESTAURANT CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   298,
#   14,
#   30,
#   '09/15/2021'],
#  ['2089345-DCA',
#   'Inactive',
#   "MCDONALD'S RESTAURANTS OF NEW YORK, INC.",
#   'NEW YORK',
#   'Enclosed',
#   281,
#   10,
#   21,
#   '06/10/2020'],
#  ['2023067-DCA',
#   'Active',
#   'ADORO LEI, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   203,
#   7,
#   14,
#   '04/15/2021'],
#  ['1310255-DCA',
#   'Active',
#   '1702 RATHBONES INC.',
#   'NEW YORK',
#   'Unenclosed',
#   224,
#   12,
#   32,
#   '04/15/2021'],
#  ['1464672-DCA',
#   'Inactive',
#   'PIO PIO OCHO INC.',
#   'NEW YORK',
#   'Unenclosed',
#   181,
#   8,
#   16,
#   '06/12/2020'],
#  ['2087051-DCA',
#   'Active',
#   '138 WEST FORDHAM RD FOOD CORP',
#   'BRONX',
#   'Unenclosed',
#   200,
#   5,
#   20,
#   '04/15/2021'],
#  ['1432061-DCA',
#   'Inactive',
#   'CLEW Z. ANGUS (USA) INC.',
#   'NEW YORK',
#   'Enclosed',
#   136,
#   5,
#   10,
#   '11/17/2019'],
#  ['1347356-DCA',
#   'Inactive',
#   "O'FLYNN ENTERPRISES LLC",
#   'NEW YORK',
#   'Unenclosed',
#   122,
#   3,
#   12,
#   '09/15/2020'],
#  ['2004736-DCA',
#   'Inactive',
#   'CLAUDISAL REST. CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   193,
#   9,
#   18,
#   '09/15/2020'],
#  ['1382861-DCA',
#   'Active',
#   'GMT NEW YORK LLC',
#   'NEW YORK',
#   'Unenclosed',
#   593,
#   26,
#   55,
#   '04/15/2021'],
#  ['1466932-DCA',
#   'Inactive',
#   'LE BILBOQUET NY, LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   176,
#   5,
#   20,
#   '06/29/2020'],
#  ['2042353-DCA',
#   'Inactive',
#   'BENVA BAKERY, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   214,
#   11,
#   25,
#   '09/15/2020'],
#  ['1136669-DCA',
#   'Inactive',
#   '62nd & 1st LLC',
#   'NEW YORK',
#   'Unenclosed',
#   417,
#   6,
#   36,
#   '09/15/2020'],
#  ['2050278-DCA',
#   'Inactive',
#   'LE BABA COOL INC',
#   'BROOKLYN',
#   'Enclosed',
#   60,
#   3,
#   6,
#   '04/16/2020'],
#  ['2079372-DCA',
#   'Inactive',
#   '27 EAST RESTAURANT HOLDINGS LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   98,
#   3,
#   12,
#   '12/15/2020'],
#  ['2020704-DCA',
#   'Active',
#   '1629 2ND RESTAURANT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   149,
#   8,
#   16,
#   '12/15/2021'],
#  ['0769760-DCA',
#   'Inactive',
#   'FIRST 69TH ST. REALTY CORP.',
#   'NEW YORK',
#   'Enclosed',
#   422,
#   17,
#   34,
#   '09/10/2020'],
#  ['2023393-DCA',
#   'Active',
#   '2580 BROADWAY INC',
#   'NEW YORK',
#   'Unenclosed',
#   161,
#   8,
#   16,
#   '09/15/2021'],
#  ['2041674-DCA',
#   'Inactive',
#   'BALTIMORE RESTAURANT INC',
#   'NEW YORK',
#   'Unenclosed',
#   120,
#   4,
#   8,
#   '12/15/2020'],
#  ['2042216-DCA',
#   'Inactive',
#   'CALEXICO 122 LLC',
#   'NEW YORK',
#   'Enclosed',
#   390,
#   11,
#   29,
#   '06/10/2020'],
#  ['2009643-DCA',
#   'Inactive',
#   'YARDBIRD LLC',
#   'NEW YORK',
#   'Unenclosed',
#   152,
#   10,
#   20,
#   '09/15/2020'],
#  ['2025635-DCA',
#   'Active',
#   '4819 VERNON KITCHEN LLC',
#   'LONG ISLAND CITY',
#   'Unenclosed',
#   379,
#   20,
#   40,
#   '04/15/2021'],
#  ['2057394-DCA',
#   'Inactive',
#   'THE PICKLE PEOPLE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   139,
#   3,
#   15,
#   '05/02/2020'],
#  ['1003195-DCA',
#   'Active',
#   'RIOMAR CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   119,
#   4,
#   13,
#   '04/15/2021'],
#  ['1466561-DCA',
#   'Active',
#   'CMH BBQ HOLDINGS, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   247,
#   11,
#   21,
#   '04/15/2021'],
#  ['2082440-DCA',
#   'Active',
#   'SENSO UNICO RESTAURANT CORP',
#   'SUNNYSIDE',
#   'Unenclosed',
#   321,
#   13,
#   26,
#   '12/15/2021'],
#  ['2089503-DCA',
#   'Active',
#   'RALPH LAUREN RETAIL INC',
#   'NEW YORK',
#   'Small Unenclosed',
#   231,
#   4,
#   7,
#   '09/15/2022'],
#  ['2035686-DCA',
#   'Inactive',
#   'GFLC MARKET LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   245,
#   10,
#   19,
#   '09/15/2020'],
#  ['2019563-DCA',
#   'Active',
#   'BF NY 82 LLC.',
#   'NEW YORK',
#   'Unenclosed',
#   39,
#   2,
#   4,
#   '09/15/2021'],
#  ['2038816-DCA',
#   'Inactive',
#   'STEINWAY LPC CORP',
#   'ASTORIA',
#   'Unenclosed',
#   96,
#   4,
#   16,
#   '09/15/2020'],
#  ['1010686-DCA',
#   'Inactive',
#   'LA RIPAILLE, CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   129,
#   4,
#   11,
#   '09/15/2020'],
#  ['2056574-DCA',
#   'Inactive',
#   'LA PETIT AMELIE, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   85,
#   4,
#   8,
#   '03/31/2020'],
#  ['1163028-DCA',
#   'Inactive',
#   'KING LUKE INC.',
#   'BROOKLYN',
#   'Unenclosed',
#   199,
#   10,
#   22,
#   '12/15/2020'],
#  ['2072713-DCA',
#   'Inactive',
#   'BOLD FOOD LAFAYETTE ST LLC',
#   'NEW YORK',
#   'Unenclosed',
#   137,
#   5,
#   10,
#   '09/15/2020'],
#  ['1423768-DCA',
#   'Inactive',
#   'A.O. CAFE AND RESTAURANT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   126,
#   6,
#   14,
#   '12/15/2020'],
#  ['1422663-DCA',
#   'Inactive',
#   'CLGM, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   171,
#   9,
#   20,
#   '09/15/2020'],
#  ['2037223-DCA',
#   'Inactive',
#   'NANCE CORP.',
#   'BROOKLYN',
#   'Unenclosed',
#   227,
#   15,
#   34,
#   '09/15/2020'],
#  ['2037395-DCA',
#   'Active',
#   'E & R U.S. VENTURES LLC',
#   'NEW YORK',
#   'Unenclosed',
#   76,
#   4,
#   8,
#   '04/15/2021'],
#  ['2038088-DCA',
#   'Inactive',
#   '1325 CCPJ CORP',
#   'NEW YORK',
#   'Unenclosed',
#   252,
#   12,
#   26,
#   '12/15/2020'],
#  ['1131159-DCA',
#   'Inactive',
#   'FOUR GREEN FIELDS LLC.',
#   'NEW YORK',
#   'Enclosed',
#   240,
#   12,
#   24,
#   '04/15/2019'],
#  ['2082893-DCA',
#   'Active',
#   'INDEPENDENT OF 23RD STREET LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   111,
#   3,
#   12,
#   '09/15/2021'],
#  ['1245257-DCA',
#   'Inactive',
#   'THE SMOKE JOINT, LLC',
#   'BROOKLYN',
#   'Enclosed',
#   161,
#   5,
#   12,
#   '06/30/2020'],
#  ['0920717-DCA',
#   'Active',
#   'THE ODEON, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   371,
#   7,
#   28,
#   '04/15/2022'],
#  ['2053880-DCA',
#   'Inactive',
#   'AURORA FG, INC',
#   'BROOKLYN',
#   'Unenclosed',
#   425,
#   20,
#   40,
#   '08/29/2020'],
#  ['2054516-DCA',
#   'Inactive',
#   'AMSTERDAM AVE BAGELS INC',
#   'NEW YORK',
#   'Unenclosed',
#   207,
#   12,
#   28,
#   '06/23/2020'],
#  ['1392177-DCA',
#   'Active',
#   'BASIL LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   234,
#   5,
#   19,
#   '04/15/2021'],
#  ['1455729-DCA',
#   'Active',
#   'DINOSAUR RESTAURANTS, LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   517,
#   6,
#   36,
#   '09/15/2021'],
#  ['2021274-DCA',
#   'Active',
#   'BUTCHER KING,INC',
#   'ASTORIA',
#   'Unenclosed',
#   143,
#   8,
#   16,
#   '12/15/2021'],
#  ['1277859-DCA',
#   'Inactive',
#   'C & O COFFEE SHOP, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   163,
#   5,
#   10,
#   '09/15/2020'],
#  ['0955674-DCA',
#   'Inactive',
#   'M.B.R.P. REST. INC.',
#   'NEW YORK',
#   'Unenclosed',
#   212,
#   12,
#   25,
#   '12/15/2020'],
#  ['2034413-DCA',
#   'Inactive',
#   'PB WEALTH INC',
#   'NEW YORK',
#   'Unenclosed',
#   70,
#   4,
#   8,
#   '09/15/2020'],
#  ['1418616-DCA',
#   'Inactive',
#   "PEDRO'S BAR & RESTAURANT, INC.",
#   'BROOKLYN',
#   'Unenclosed',
#   280,
#   7,
#   13,
#   '03/27/2020'],
#  ['2019225-DCA',
#   'Active',
#   'JUICE GENERATION 13 INC',
#   'NEW YORK',
#   'Unenclosed',
#   153,
#   8,
#   16,
#   '04/15/2021'],
#  ['1354206-DCA',
#   'Inactive',
#   'MEDPARK-30 LLC',
#   'NEW YORK',
#   'Unenclosed',
#   102,
#   6,
#   12,
#   '09/15/2020'],
#  ['1421278-DCA',
#   'Inactive',
#   'BLUE SMOKE 102 NORTH END AVE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   311,
#   12,
#   28,
#   '12/15/2020'],
#  ['1428232-DCA',
#   'Inactive',
#   'SOUTH LAKE HOSPITALITY GROUP INC.',
#   'NEW YORK',
#   'Unenclosed',
#   180,
#   5,
#   19,
#   '05/08/2020'],
#  ['1067914-DCA',
#   'Inactive',
#   "BENNY'S BURRITOS, INC.",
#   'NEW YORK',
#   'Unenclosed',
#   345,
#   8,
#   24,
#   '12/15/2020'],
#  ['1251412-DCA',
#   'Active',
#   "SAMMY'S S.B. REST. CORP.",
#   'BRONX',
#   'Unenclosed',
#   426,
#   9,
#   34,
#   '03/31/2020'],
#  ['1277876-DCA',
#   'Inactive',
#   'LA SCALA RESTAURANT, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   455,
#   11,
#   34,
#   '09/15/2020'],
#  ['2082017-DCA',
#   'Active',
#   'ME7782 LLC',
#   'LONG ISLAND CITY',
#   'Unenclosed',
#   235,
#   11,
#   22,
#   '04/15/2021'],
#  ['1022739-DCA',
#   'Inactive',
#   'TERMINUS RESTAURANT ASSOCIATES LLC',
#   'NEW YORK',
#   'Enclosed',
#   371,
#   14,
#   28,
#   '08/24/2020'],
#  ['2088886-DCA',
#   'Active',
#   'PLANT SHED PRINCE, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   301,
#   18,
#   36,
#   '09/15/2021'],
#  ['2052743-DCA',
#   'Inactive',
#   'RENZAN SUSHI CORPORATION',
#   'NEW YORK',
#   'Unenclosed',
#   230,
#   12,
#   24,
#   '04/14/2020'],
#  ['2028884-DCA',
#   'Active',
#   'VILLAGE RESTAURANT GROUP LLC',
#   'NEW YORK',
#   'Unenclosed',
#   138,
#   6,
#   12,
#   '12/15/2021'],
#  ['1465870-DCA',
#   'Inactive',
#   'PQ EAST 83RD ST, INC',
#   'NEW YORK',
#   'Unenclosed',
#   226,
#   10,
#   22,
#   '03/27/2020'],
#  ['1094184-DCA',
#   'Inactive',
#   "DANA'S LLC",
#   'NEW YORK',
#   'Unenclosed',
#   565,
#   24,
#   46,
#   '08/31/2020'],
#  ['2067782-DCA',
#   'Inactive',
#   'SHADMOOR LLC',
#   'NEW YORK',
#   'Unenclosed',
#   286,
#   11,
#   22,
#   '12/15/2020'],
#  ['1355808-DCA',
#   'Inactive',
#   '149 SECOND AVE. REST. INC.',
#   'NEW YORK',
#   'Unenclosed',
#   215,
#   6,
#   22,
#   '12/15/2020'],
#  ['1206030-DCA',
#   'Inactive',
#   'ARRIBA ARRIBA MEXICAN RESTAURANTS, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   285,
#   8,
#   14,
#   '04/13/2020'],
#  ['1190049-DCA',
#   'Active',
#   'HORSESHOES NY INC.',
#   'NEW YORK',
#   'Unenclosed',
#   91,
#   4,
#   8,
#   '09/15/2021'],
#  ['2033303-DCA',
#   'Inactive',
#   'VEGG 58TH LLC',
#   'NEW YORK',
#   'Unenclosed',
#   130,
#   8,
#   16,
#   '09/05/2020'],
#  ['2086169-DCA',
#   'Active',
#   'Center Blvd Restaurant LLC',
#   'LONG ISLAND CITY',
#   'Unenclosed',
#   646,
#   12,
#   48,
#   '09/15/2021'],
#  ['2083473-DCA',
#   'Active',
#   'LOCKSMITH WINE BAR INC',
#   'NEW YORK',
#   'Unenclosed',
#   247,
#   10,
#   20,
#   '09/15/2021'],
#  ['2043057-DCA',
#   'Inactive',
#   'NEW INDIAN FOODS LLC',
#   'NEW YORK',
#   'Unenclosed',
#   175,
#   11,
#   22,
#   '02/15/2020'],
#  ['2021585-DCA',
#   'Active',
#   'JACH RESTAURANT CORP',
#   'NEW YORK',
#   'Unenclosed',
#   223,
#   10,
#   20,
#   '04/15/2021'],
#  ['1378763-DCA',
#   'Inactive',
#   '135 STUDIO N ADR, INC.',
#   'BROOKLYN',
#   'Unenclosed',
#   124,
#   5,
#   11,
#   '09/15/2020'],
#  ['2044806-DCA',
#   'Active',
#   'UNION SQ 4TH F & B MANAGEMENT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   287,
#   14,
#   32,
#   '09/15/2021'],
#  ['2086171-DCA',
#   'Active',
#   'JOE & THE JUICE NEW YORK, LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   205,
#   4,
#   8,
#   '04/15/2021'],
#  ['2035683-DCA',
#   'Inactive',
#   'RHLP 284 LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   156,
#   6,
#   12,
#   '09/15/2020'],
#  ['1249100-DCA',
#   'Inactive',
#   'P & A 665 RESTAURANT CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   364,
#   13,
#   38,
#   '07/21/2020'],
#  ['1360728-DCA',
#   'Inactive',
#   'MUSSELS & MORE, LTD.',
#   'BROOKLYN',
#   'Unenclosed',
#   432,
#   17,
#   34,
#   '12/15/2018'],
#  ['1167909-DCA',
#   'Inactive',
#   'THIERRY INC.',
#   'NEW YORK',
#   'Small Unenclosed',
#   137,
#   6,
#   17,
#   '09/15/2020'],
#  ['0852766-DCA',
#   'Active',
#   'LAMARCA INC.',
#   'NEW YORK',
#   'Enclosed',
#   142,
#   5,
#   10,
#   '04/30/2020'],
#  ['1346116-DCA',
#   'Inactive',
#   'TRES DE MEXICO, LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   75,
#   4,
#   8,
#   '09/15/2020'],
#  ['1239318-DCA',
#   'Inactive',
#   'LENWICH 77TH LLC',
#   'NEW YORK',
#   'Enclosed',
#   272,
#   9,
#   24,
#   '09/15/2020'],
#  ['2019226-DCA',
#   'Active',
#   'MAGIC FOOD CORPORATION',
#   'ASTORIA',
#   'Unenclosed',
#   140,
#   6,
#   14,
#   '09/15/2021'],
#  ['2074050-DCA',
#   'Inactive',
#   'NYCBCH III, INC',
#   'ASTORIA',
#   'Unenclosed',
#   82,
#   6,
#   11,
#   '12/15/2020'],
#  ['1174880-DCA',
#   'Inactive',
#   'THAFATH, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   166,
#   8,
#   17,
#   '12/15/2020'],
#  ['2088124-DCA',
#   'Inactive',
#   'THE BEE FACTORY LLC',
#   'ASTORIA',
#   'Unenclosed',
#   703,
#   36,
#   72,
#   '06/09/2020'],
#  ['1414471-DCA',
#   'Inactive',
#   'TRIM CASTLE CORP.',
#   'NEW YORK',
#   'Enclosed',
#   116,
#   8,
#   21,
#   '04/21/2020'],
#  ['2047696-DCA',
#   'Active',
#   'CAFE CORTADITO LLC',
#   'NEW YORK',
#   'Unenclosed',
#   105,
#   6,
#   12,
#   '09/15/2021'],
#  ['2011216-DCA',
#   'Inactive',
#   'REGULAR WOW LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   357,
#   17,
#   36,
#   '09/15/2020'],
#  ['1171759-DCA',
#   'Inactive',
#   'K.K. & D. OF 79TH ST. REST. CORP.',
#   'NEW YORK',
#   'Small Unenclosed',
#   163,
#   3,
#   12,
#   '09/15/2020'],
#  ['2009822-DCA',
#   'Inactive',
#   '59 MACT CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   110,
#   7,
#   14,
#   '12/15/2020'],
#  ['2038230-DCA',
#   'Inactive',
#   'BOWERY HOSPITALITY ASSOCIATES LLC',
#   'NEW YORK',
#   'Unenclosed',
#   753,
#   18,
#   54,
#   '12/15/2020'],
#  ['1468690-DCA',
#   'Inactive',
#   '243 E. 14TH CAFE INC.',
#   'NEW YORK',
#   'Small Unenclosed',
#   124,
#   3,
#   12,
#   '07/03/2020'],
#  ['2054417-DCA',
#   'Active',
#   'CATERED BY PERGOLA LLC',
#   'NEW YORK',
#   'Regular Unenclosed/Small Unenclosed',
#   95,
#   6,
#   14,
#   '04/15/2021'],
#  ['2075388-DCA',
#   'Inactive',
#   'GREEN 84, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   356,
#   14,
#   28,
#   '12/15/2020'],
#  ['1240086-DCA',
#   'Inactive',
#   'PAESANO REST. CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   97,
#   3,
#   6,
#   '09/15/2020'],
#  ['2055693-DCA',
#   'Active',
#   'VLC UPPER WEST, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   81,
#   4,
#   8,
#   '09/15/2021'],
#  ['1454964-DCA',
#   'Active',
#   '18 GREENWICH AVENUE, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   183,
#   8,
#   16,
#   '04/17/2020'],
#  ['1034831-DCA',
#   'Active',
#   '177 CHRYSTIE INC.',
#   'NEW YORK',
#   'Unenclosed',
#   501,
#   15,
#   31,
#   '04/15/2021'],
#  ['2089139-DCA',
#   'Inactive',
#   'TRIPTI, INC.',
#   'NEW YORK',
#   'Enclosed',
#   269,
#   10,
#   24,
#   '07/20/2020'],
#  ['2082510-DCA',
#   'Inactive',
#   '2791 BROADWAY RESTAURANT GROUP LLC',
#   'NEW YORK',
#   'Enclosed',
#   548,
#   15,
#   52,
#   '11/24/2020'],
#  ['1344043-DCA',
#   'Inactive',
#   'A & D WINE CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   190,
#   10,
#   22,
#   '09/15/2020'],
#  ['2063825-DCA',
#   'Inactive',
#   'THANA REST INC.',
#   'NEW YORK',
#   'Unenclosed',
#   362,
#   20,
#   40,
#   '03/26/2020'],
#  ['2023883-DCA',
#   'Active',
#   'MERMAID 88 LLC',
#   'NEW YORK',
#   'Unenclosed',
#   273,
#   15,
#   34,
#   '09/15/2021'],
#  ['1283230-DCA',
#   'Inactive',
#   '600 WEST 169TH REST. INC.',
#   'NEW YORK',
#   'Unenclosed',
#   360,
#   22,
#   44,
#   '12/15/2020'],
#  ['2032176-DCA',
#   'Inactive',
#   'BEL AIR DINER INC',
#   'ASTORIA',
#   'Unenclosed',
#   464,
#   13,
#   26,
#   '09/15/2020'],
#  ['2023401-DCA',
#   'Active',
#   'ROOT & BONE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   274,
#   12,
#   24,
#   '04/15/2021'],
#  ['2028015-DCA',
#   'Active',
#   'MAYFAIR WEST AT CHELSEA MARKET LLC',
#   'NEW YORK',
#   'Unenclosed',
#   247,
#   6,
#   18,
#   '04/15/2021'],
#  ['1388457-DCA',
#   'Active',
#   'ELI-LILLA, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   175,
#   9,
#   22,
#   '04/15/2021'],
#  ['2037220-DCA',
#   'Inactive',
#   'JIN UPPER WEST SIDE CORP',
#   'NEW YORK',
#   'Unenclosed',
#   150,
#   8,
#   18,
#   '12/15/2020'],
#  ['2004096-DCA',
#   'Inactive',
#   'E & E RESTAURANT 2, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   138,
#   7,
#   14,
#   '09/15/2020'],
#  ['2077794-DCA',
#   'Inactive',
#   'SOUTH 4TH RESTAURANT COMPANY LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   172,
#   9,
#   18,
#   '12/15/2020'],
#  ['2005253-DCA',
#   'Inactive',
#   'KENNEDY ORGANICS LLC',
#   'NEW YORK',
#   'Unenclosed',
#   614,
#   19,
#   38,
#   '09/15/2020'],
#  ['2059065-DCA',
#   'Active',
#   "SAL'S FAMILY PIZZA, INC",
#   'NEW YORK',
#   'Unenclosed',
#   98,
#   6,
#   12,
#   '04/15/2021'],
#  ['1415773-DCA',
#   'Inactive',
#   'MS RESTAURANT OWNERS LLC',
#   'NEW YORK',
#   'Enclosed',
#   191,
#   8,
#   24,
#   '04/13/2020'],
#  ['1150943-DCA',
#   'Inactive',
#   'GROTTA AZZURRA INN INC.',
#   'NEW YORK',
#   'Unenclosed',
#   326,
#   20,
#   40,
#   '09/15/2020'],
#  ['1188827-DCA',
#   'Inactive',
#   'POINT JUDITH, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   146,
#   8,
#   16,
#   '04/15/2021'],
#  ['1347915-DCA',
#   'Inactive',
#   'VIDA MEXICANA INC.',
#   'NEW YORK',
#   'Unenclosed',
#   438,
#   18,
#   36,
#   '07/16/2020'],
#  ['1299629-DCA',
#   'Inactive',
#   'GREEK KITCHEN INC.',
#   'NEW YORK',
#   'Enclosed',
#   447,
#   13,
#   26,
#   '07/11/2020'],
#  ['1189655-DCA',
#   'Inactive',
#   'SBCPS, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   256,
#   10,
#   20,
#   '08/29/2020'],
#  ['2018722-DCA',
#   'Inactive',
#   'EAT MADISON 91 LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   291,
#   8,
#   28,
#   '12/15/2020'],
#  ['1250013-DCA',
#   'Inactive',
#   'PANZI ENTERPRISES LLC',
#   'NEW YORK',
#   'Unenclosed',
#   340,
#   13,
#   36,
#   '04/06/2020'],
#  ['1420945-DCA',
#   'Active',
#   'F-C LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   192,
#   8,
#   16,
#   '04/15/2022'],
#  ['1377344-DCA',
#   'Inactive',
#   'SALVATORES OF SOHO, INC.',
#   'BRONX',
#   'Unenclosed',
#   380,
#   17,
#   42,
#   '12/15/2020'],
#  ['1385278-DCA',
#   'Inactive',
#   '170 BEDFORD RESTAURANT LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   52,
#   3,
#   6,
#   '03/20/2020'],
#  ['2085978-DCA',
#   'Active',
#   'ISABELLA LIMON LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   251,
#   6,
#   12,
#   '12/15/2021'],
#  ['1420047-DCA',
#   'Inactive',
#   'NO MOORE OYSTERS LLC',
#   'NEW YORK',
#   'Unenclosed',
#   81,
#   4,
#   8,
#   '06/21/2020'],
#  ['1459845-DCA',
#   'Active',
#   'TWO BIKES, LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   134,
#   6,
#   12,
#   '04/15/2021'],
#  ['2006658-DCA',
#   'Inactive',
#   'LE BON NY CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   158,
#   5,
#   10,
#   '05/18/2020'],
#  ['1003313-DCA',
#   'Active',
#   'J.P.G. LLC',
#   'NEW YORK',
#   'Unenclosed',
#   169,
#   9,
#   18,
#   '09/15/2021'],
#  ['2082015-DCA',
#   'Active',
#   'LYH DITMARS HOSPITALITY CORP',
#   'ASTORIA',
#   'Unenclosed',
#   134,
#   4,
#   12,
#   '04/15/2021'],
#  ['1454468-DCA',
#   'Inactive',
#   'TIN MARIN BAR & LOUNGE, INC.',
#   'BRONX',
#   'Unenclosed',
#   146,
#   7,
#   14,
#   '08/18/2020'],
#  ['1254785-DCA',
#   'Active',
#   'BOWERY F & B, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   376,
#   18,
#   48,
#   '04/15/2021'],
#  ['1381014-DCA',
#   'Inactive',
#   'PQ CARNEGIE HILL, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   126,
#   4,
#   8,
#   '12/15/2020'],
#  ['2006950-DCA',
#   'Inactive',
#   'GREEK TAVERNA LLC',
#   'ASTORIA',
#   'Unenclosed',
#   143,
#   6,
#   12,
#   '12/15/2020'],
#  ['2080300-DCA',
#   'Inactive',
#   "CARRIE'S HOSPITALITY, LLC",
#   'BROOKLYN',
#   'Unenclosed',
#   235,
#   11,
#   22,
#   '12/15/2020'],
#  ['2057395-DCA',
#   'Active',
#   'TUFINO PIZZERIA NAPOLETANA INC',
#   'ASTORIA',
#   'Unenclosed',
#   119,
#   6,
#   14,
#   '04/15/2021'],
#  ['2088548-DCA',
#   'Active',
#   'HLD COLUMBUS LLC',
#   'NEW YORK',
#   'Unenclosed',
#   198,
#   9,
#   19,
#   '12/15/2021'],
#  ['2043296-DCA',
#   'Inactive',
#   'BOUCHERIE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   518,
#   42,
#   84,
#   '09/15/2020'],
#  ['2084767-DCA',
#   'Active',
#   '3 Richardson Mexico LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   397,
#   20,
#   45,
#   '04/15/2021'],
#  ['2087678-DCA',
#   'Active',
#   'BOCADITOS BISTRO & EXPRESSO BAR LLC',
#   'NEW YORK',
#   'Unenclosed',
#   273,
#   12,
#   24,
#   '12/15/2021'],
#  ['1219506-DCA',
#   'Inactive',
#   'PLAZA PATISSERIE, INC.',
#   'ASTORIA',
#   'Unenclosed',
#   476,
#   14,
#   37,
#   '09/15/2020'],
#  ['2083475-DCA',
#   'Active',
#   'SECOND AVE RESTAURANT GROUP INC.',
#   'NEW YORK',
#   'Unenclosed',
#   46,
#   5,
#   11,
#   '04/15/2021'],
#  ['1376493-DCA',
#   'Inactive',
#   'MOTTSU CUISINE INC.',
#   'NEW YORK',
#   'Unenclosed',
#   86,
#   6,
#   12,
#   '09/15/2020'],
#  ['1418169-DCA',
#   'Inactive',
#   'SUN OF MAY, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   500,
#   32,
#   68,
#   '09/15/2020'],
#  ['1459624-DCA',
#   'Inactive',
#   'SHIP WRECKED BAR AND GRILL, INC.',
#   'NEW YORK',
#   'Enclosed',
#   110,
#   5,
#   9,
#   '08/11/2020'],
#  ['2086172-DCA',
#   'Active',
#   'PIZZA 84 LLC',
#   'NEW YORK',
#   'Unenclosed',
#   162,
#   9,
#   22,
#   '12/15/2021'],
#  ['1382062-DCA',
#   'Inactive',
#   '753 WASHINGTON TRATTORIA INC.',
#   'NEW YORK',
#   'Unenclosed',
#   267,
#   10,
#   24,
#   '04/15/2020'],
#  ['2057407-DCA',
#   'Active',
#   "UNCLE JACK'S MEAT COMPANY ASTORIA, INC",
#   'ASTORIA',
#   'Unenclosed',
#   273,
#   15,
#   30,
#   '04/15/2021'],
#  ['1318210-DCA',
#   'Inactive',
#   'WATAWA INC.',
#   'ASTORIA',
#   'Unenclosed',
#   252,
#   10,
#   26,
#   '12/15/2020'],
#  ['2038956-DCA',
#   'Inactive',
#   'NJJMJ INC',
#   'NEW YORK',
#   'Unenclosed',
#   98,
#   5,
#   10,
#   '09/15/2020'],
#  ['2085255-DCA',
#   'Active',
#   'GYRO KING FOODS CORP.',
#   'BRONX',
#   'Unenclosed',
#   127,
#   8,
#   24,
#   '04/15/2021'],
#  ['1469750-DCA',
#   'Inactive',
#   'BUBBYS MP LLC',
#   'NEW YORK',
#   'Unenclosed',
#   727,
#   33,
#   70,
#   '06/29/2020'],
#  ['2059550-DCA',
#   'Inactive',
#   'SWEET CHICK FLATBUSH LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   328,
#   14,
#   34,
#   '04/21/2020'],
#  ['2086429-DCA',
#   'Active',
#   'ESPRESSO BOOKSTORE & CAFE BROADWAY LLC',
#   'NEW YORK',
#   'Unenclosed',
#   232,
#   8,
#   16,
#   '09/15/2021'],
#  ['2064661-DCA',
#   'Inactive',
#   'CMR REST CORP',
#   'NEW YORK',
#   'Unenclosed',
#   200,
#   8,
#   19,
#   '04/06/2020'],
#  ['2067784-DCA',
#   'Inactive',
#   'WMW REST II, LLC',
#   'NEW YORK',
#   'Regular Unenclosed/Small Unenclosed',
#   157,
#   6,
#   12,
#   '12/15/2020'],
#  ['1222176-DCA',
#   'Inactive',
#   'SILVER MOON BAKERY, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   261,
#   15,
#   30,
#   '09/15/2020'],
#  ['0885881-DCA',
#   'Active',
#   '83/AMSTERDAM RESTAURANT CORP.',
#   'NEW YORK',
#   'Enclosed',
#   212,
#   6,
#   16,
#   '05/15/2021'],
#  ['2002646-DCA',
#   'Inactive',
#   '229 BLEECKER LLC',
#   'NEW YORK',
#   'Unenclosed',
#   332,
#   16,
#   32,
#   '09/15/2020'],
#  ['2071243-DCA',
#   'Inactive',
#   'FUSHA FUSION RESTAURANT INC',
#   'NEW YORK',
#   'Small Unenclosed',
#   93,
#   6,
#   12,
#   '09/15/2020'],
#  ['2071746-DCA',
#   'Inactive',
#   '1 PERRY LLC',
#   'NEW YORK',
#   'Unenclosed',
#   137,
#   7,
#   16,
#   '09/15/2020'],
#  ['1469471-DCA',
#   'Active',
#   '14 SPRING STREET CAFE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   75,
#   2,
#   8,
#   '04/15/2021'],
#  ['2027039-DCA',
#   'Active',
#   'KISMAT INDIAN RESTAURANT INC',
#   'NEW YORK',
#   'Unenclosed',
#   432,
#   28,
#   56,
#   '09/15/2021'],
#  ['1170078-DCA',
#   'Inactive',
#   'IGUANA NEW YORK, LTD.',
#   'NEW YORK',
#   'Small Unenclosed',
#   294,
#   5,
#   17,
#   '12/15/2020'],
#  ['2041096-DCA',
#   'Inactive',
#   '1600 AMSTERDAM HARLEM GROUP, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   226,
#   12,
#   24,
#   '09/15/2020'],
#  ['2087609-DCA',
#   'Active',
#   'MOSS CAFE LLC',
#   'BRONX',
#   'Unenclosed',
#   66,
#   2,
#   4,
#   '09/15/2021'],
#  ['2076189-DCA',
#   'Inactive',
#   'LAS MARGARITAS SUNSET INC',
#   'ASTORIA',
#   'Unenclosed',
#   423,
#   11,
#   44,
#   '09/15/2020'],
#  ['1076713-DCA',
#   'Inactive',
#   'I MALATESTA TRATTORIA INC.',
#   'NEW YORK',
#   'Unenclosed',
#   333,
#   18,
#   35,
#   '09/25/2020'],
#  ['2022426-DCA',
#   'Active',
#   'ANGEL OF HARLEM LLC',
#   'NEW YORK',
#   'Unenclosed',
#   549,
#   17,
#   42,
#   '09/15/2021'],
#  ['2049156-DCA',
#   'Active',
#   'THE ALCOVE RESTAURANT INC',
#   'SUNNYSIDE',
#   'Unenclosed',
#   102,
#   4,
#   12,
#   '09/15/2021'],
#  ['2020669-DCA',
#   'Inactive',
#   'TOZZER LTD',
#   'NEW YORK',
#   'Unenclosed',
#   234,
#   10,
#   20,
#   '09/15/2020'],
#  ['1277414-DCA',
#   'Inactive',
#   'SHANNON CAFE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   113,
#   4,
#   8,
#   '12/15/2020'],
#  ['2082167-DCA',
#   'Active',
#   'SURELY YOU MUST BE KIDDING LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   322,
#   13,
#   26,
#   '04/15/2021'],
#  ['2060036-DCA',
#   'Active',
#   'La Luna Deli &Cafe Inc.',
#   'ASTORIA',
#   'Unenclosed',
#   130,
#   4,
#   14,
#   '09/15/2021'],
#  ['2082896-DCA',
#   'Active',
#   'WHITE WALKER LLC',
#   'NEW YORK',
#   'Unenclosed',
#   192,
#   7,
#   17,
#   '09/15/2021'],
#  ['1347119-DCA',
#   'Inactive',
#   'CLAY FARM, LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   180,
#   5,
#   20,
#   '09/15/2020'],
#  ['2039433-DCA',
#   'Inactive',
#   'JOYFUL EATS LLC',
#   'NEW YORK',
#   'Unenclosed',
#   116,
#   6,
#   12,
#   '09/15/2020'],
#  ['2019774-DCA',
#   'Active',
#   'LAFITTE LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   325,
#   14,
#   28,
#   '12/15/2021'],
#  ['1382366-DCA',
#   'Inactive',
#   'SUD123 INCORPORATED',
#   'NEW YORK',
#   'Unenclosed',
#   171,
#   9,
#   19,
#   '03/19/2020'],
#  ['0920440-DCA',
#   'Inactive',
#   'JO-RACH, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   125,
#   3,
#   10,
#   '12/15/2020'],
#  ['2070813-DCA',
#   'Inactive',
#   'EGS, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   413,
#   15,
#   44,
#   '09/15/2020'],
#  ['2038459-DCA',
#   'Inactive',
#   'BROOKLYN BURGERS LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   382,
#   7,
#   28,
#   '09/15/2020'],
#  ['2019767-DCA',
#   'Active',
#   '12 CHAIRS BYN LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   237,
#   17,
#   34,
#   '04/15/2021'],
#  ['2085586-DCA',
#   'Active',
#   'ARGOT ENTERPRISE, INC',
#   'NEW YORK',
#   'Unenclosed',
#   81,
#   6,
#   12,
#   '09/15/2021'],
#  ['1247422-DCA',
#   'Inactive',
#   'TB 584 AMSTERDAM REST. CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   280,
#   12,
#   24,
#   '03/17/2020'],
#  ['1027923-DCA',
#   'Inactive',
#   'MARLOW, INC.',
#   'BROOKLYN',
#   'Unenclosed',
#   337,
#   12,
#   24,
#   '09/15/2020'],
#  ['2081572-DCA',
#   'Active',
#   'SAMPA RESTAURANT LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   165,
#   8,
#   20,
#   '04/15/2022'],
#  ['2036320-DCA',
#   'Inactive',
#   'UPPER WEST HOSPITALITY LLC',
#   'NEW YORK',
#   'Unenclosed',
#   185,
#   12,
#   20,
#   '12/15/2020'],
#  ['1467229-DCA',
#   'Inactive',
#   'DOWNTOWN DINING LLC',
#   'New York',
#   'Unenclosed',
#   379,
#   10,
#   20,
#   '03/26/2020'],
#  ['2075392-DCA',
#   'Inactive',
#   'MAMACHA LLC',
#   'NEW YORK',
#   'Unenclosed',
#   111,
#   9,
#   18,
#   '12/15/2020'],
#  ['2056097-DCA',
#   'Active',
#   'JAKK LLC',
#   'SUNNYSIDE',
#   'Unenclosed',
#   392,
#   15,
#   30,
#   '04/15/2021'],
#  ['1287126-DCA',
#   'Inactive',
#   'BB AT 55TH & 5TH, LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   176,
#   3,
#   6,
#   '09/15/2020'],
#  ['1075763-DCA',
#   'Inactive',
#   'BROADWAY & 166TH, L.L.C.',
#   'NEW YORK',
#   'Enclosed',
#   411,
#   19,
#   48,
#   '05/31/2020'],
#  ['0978960-DCA',
#   'Inactive',
#   'ST. JAMES ASSOCIATES, L.P.',
#   'NEW YORK',
#   'Unenclosed',
#   214,
#   8,
#   16,
#   '03/15/2020'],
#  ['2028372-DCA',
#   'Active',
#   'TAIKAI INC',
#   'NEW YORK',
#   'Unenclosed',
#   177,
#   9,
#   17,
#   '12/15/2021'],
#  ['2021725-DCA',
#   'Active',
#   'SANGEO CORP',
#   'BRONX',
#   'Enclosed',
#   178,
#   3,
#   15,
#   '05/15/2021'],
#  ['1343042-DCA',
#   'Inactive',
#   '188 AVE A TAKE OUT FOOD CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   286,
#   14,
#   28,
#   '12/15/2020'],
#  ['2075390-DCA',
#   'Inactive',
#   'JOE & THE JUICE NEW YORK LLC',
#   'NEW YORK',
#   'Unenclosed',
#   177,
#   4,
#   8,
#   '12/15/2020'],
#  ['1001063-DCA',
#   'Active',
#   '112 FRENCH, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   741,
#   26,
#   88,
#   '09/15/2021'],
#  ['1390391-DCA',
#   'Active',
#   'HERSHA HOSPITALITY MANAGEMENT L.P.',
#   'BROOKLYN',
#   'Unenclosed',
#   416,
#   25,
#   52,
#   '04/15/2021'],
#  ['1326142-DCA',
#   'Inactive',
#   '68TH ST CAFE INC.',
#   'NEW YORK',
#   'Unenclosed',
#   285,
#   14,
#   28,
#   '12/15/2020'],
#  ['2024391-DCA',
#   'Active',
#   'ZUPPANYC LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   207,
#   10,
#   22,
#   '04/15/2021'],
#  ['2092914-DCA',
#   'Active',
#   'BLEEKER STREET PIZZA CORP',
#   'NEW YORK',
#   'Unenclosed',
#   207,
#   6,
#   12,
#   '12/15/2022'],
#  ['2092263-DCA',
#   'Inactive',
#   'CARA JECM LLC',
#   'NEW YORK',
#   'Enclosed',
#   735,
#   21,
#   52,
#   '08/29/2020'],
#  ['1192697-DCA',
#   'Active',
#   'RAMBLING HOUSE INC.',
#   'BRONX',
#   'Unenclosed',
#   300,
#   17,
#   34,
#   '04/15/2021'],
#  ['2032459-DCA',
#   'Inactive',
#   'Elmer Kennedy LLC',
#   'NEW YORK',
#   'Unenclosed',
#   118,
#   6,
#   12,
#   '09/15/2020'],
#  ['1116343-DCA',
#   'Inactive',
#   'REBA REALTY CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   488,
#   15,
#   37,
#   '09/15/2020'],
#  ['1310982-DCA',
#   'Inactive',
#   'SEAN OG ENTERPRISES LLC',
#   'WOODSIDE',
#   'Unenclosed',
#   342,
#   15,
#   30,
#   '05/18/2020'],
#  ['2004071-DCA',
#   'Active',
#   'SLJ BAR LLC',
#   'NEW YORK',
#   'Unenclosed',
#   245,
#   13,
#   27,
#   '06/10/2020'],
#  ['2053413-DCA',
#   'Active',
#   'PASTAIAT INC',
#   'NEW YORK',
#   'Unenclosed',
#   77,
#   4,
#   8,
#   '09/15/2021'],
#  ['2009866-DCA',
#   'Inactive',
#   'CEDAR DRIVE LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   173,
#   10,
#   22,
#   '09/15/2020'],
#  ['2092915-DCA',
#   'Active',
#   'NORIKOH K.O.H. INC',
#   'NEW YORK',
#   'Unenclosed',
#   440,
#   10,
#   20,
#   '04/15/2021'],
#  ['2011961-DCA',
#   'Active',
#   'UBER CAFFE, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   75,
#   6,
#   12,
#   '04/15/2022'],
#  ['2087607-DCA',
#   'Active',
#   'D&D CAFE LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   327,
#   19,
#   38,
#   '04/15/2021'],
#  ['2077333-DCA',
#   'Inactive',
#   'HAKU TEN INC',
#   'BROOKLYN',
#   'Unenclosed',
#   84,
#   4,
#   10,
#   '09/15/2020'],
#  ['2023941-DCA',
#   'Active',
#   'WEST SIDE STEAKHOUSE, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   148,
#   4,
#   12,
#   '04/15/2021'],
#  ['2087056-DCA',
#   'Active',
#   'BAYRIDGE HOSPITALITY GROUP LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   335,
#   15,
#   30,
#   '09/15/2021'],
#  ['1381793-DCA',
#   'Active',
#   'GARDEN CAFE ASSOCIATES LLC',
#   'NEW YORK',
#   'Unenclosed',
#   198,
#   5,
#   20,
#   '09/15/2021'],
#  ['1416762-DCA',
#   'Inactive',
#   'NEW YORK BEER CO. LLC',
#   'NEW YORK',
#   'Unenclosed',
#   207,
#   9,
#   18,
#   '12/15/2020'],
#  ['2030561-DCA',
#   'Active',
#   'BAGEL ON MURRAY STREET, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   223,
#   4,
#   8,
#   '04/15/2021'],
#  ['1160623-DCA',
#   'Active',
#   "WOGIE'S, INC.",
#   'NEW YORK',
#   'Unenclosed',
#   297,
#   14,
#   28,
#   '09/15/2020'],
#  ['2039149-DCA',
#   'Inactive',
#   'NOCHE DE MARGARITAS RESTAURANT INC',
#   'NEW YORK',
#   'Unenclosed',
#   70,
#   4,
#   8,
#   '09/15/2020'],
#  ['2086430-DCA',
#   'Active',
#   'NOGLU NEW YORK LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   36,
#   2,
#   4,
#   '12/15/2021'],
#  ['2011155-DCA',
#   'Inactive',
#   'GREENWICH BBQ LLC',
#   'NEW YORK',
#   'Unenclosed',
#   200,
#   10,
#   20,
#   '02/01/2020'],
#  ['2083471-DCA',
#   'Active',
#   'JUICERIE IV LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   740,
#   15,
#   54,
#   '04/15/2021'],
#  ['1133602-DCA',
#   'Inactive',
#   'Y.N.L.C. CAFE CORP.',
#   'ASTORIA',
#   'Unenclosed',
#   862,
#   31,
#   62,
#   '12/15/2020'],
#  ['2067783-DCA',
#   'Inactive',
#   'SOHO MARKET & BEER MERCHANTS INC',
#   'NEW YORK',
#   'Unenclosed',
#   210,
#   10,
#   26,
#   '09/15/2020'],
#  ['1342588-DCA',
#   'Inactive',
#   'NEW RESTART INC.',
#   'NEW YORK',
#   'Unenclosed',
#   98,
#   8,
#   16,
#   '12/15/2020'],
#  ['1416725-DCA',
#   'Active',
#   'IDG SEAPORT CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   203,
#   12,
#   24,
#   '04/15/2021'],
#  ['1454085-DCA',
#   'Active',
#   '1679 3RD AVENUE RESTAURANT CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   407,
#   19,
#   45,
#   '04/15/2021'],
#  ['1312021-DCA',
#   'Active',
#   'LX AVENUE BAGELS, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   35,
#   4,
#   8,
#   '04/15/2021'],
#  ['1384470-DCA',
#   'Active',
#   "SARABETH'S TRIBECA, LLC",
#   'NEW YORK',
#   'Unenclosed',
#   300,
#   12,
#   26,
#   '12/15/2022'],
#  ['2090719-DCA',
#   'Inactive',
#   'HEX EAST, LLC',
#   'NEW YORK',
#   'Enclosed',
#   359,
#   12,
#   32,
#   '08/15/2020'],
#  ['2070749-DCA',
#   'Inactive',
#   'EL CONDE M&G INC',
#   'NEW YORK',
#   'Enclosed',
#   280,
#   7,
#   28,
#   '02/15/2020'],
#  ['1422856-DCA',
#   'Inactive',
#   'TESSA & LUCHO, INC.',
#   'BROOKLYN',
#   'Unenclosed',
#   197,
#   6,
#   12,
#   '09/15/2020'],
#  ['2025568-DCA',
#   'Active',
#   'DEED LLC',
#   'BROOKLYN',
#   'Small Unenclosed',
#   264,
#   3,
#   12,
#   '12/15/2022'],
#  ['2052885-DCA',
#   'Active',
#   'SJD 220 CORP',
#   'BROOKLYN',
#   'Unenclosed',
#   89,
#   3,
#   6,
#   '04/15/2021'],
#  ['2047685-DCA',
#   'Active',
#   "MARTHA'S 263 BEDFORD AVE LLC",
#   'BROOKLYN',
#   'Small Unenclosed',
#   420,
#   14,
#   28,
#   '04/15/2021'],
#  ['2022428-DCA',
#   'Active',
#   'HAMILTON POINT GRANARY LLC',
#   'NEW YORK',
#   'Unenclosed',
#   189,
#   7,
#   14,
#   '12/15/2021'],
#  ['2071250-DCA',
#   'Inactive',
#   'UNCLE BIAGIO, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   319,
#   7,
#   14,
#   '12/15/2020'],
#  ['2023861-DCA',
#   'Active',
#   '1754 REST INC.',
#   'NEW YORK',
#   'Unenclosed',
#   151,
#   12,
#   24,
#   '04/15/2021'],
#  ['2086720-DCA',
#   'Active',
#   'SIRICHAI INC',
#   'NEW YORK',
#   'Unenclosed',
#   211,
#   5,
#   16,
#   '12/15/2021'],
#  ['1189217-DCA',
#   'Active',
#   'PEPRICO INC.',
#   'NEW YORK',
#   'Unenclosed',
#   116,
#   8,
#   16,
#   '04/15/2021'],
#  ['1025180-DCA',
#   'Inactive',
#   'GRILLO, LTD.',
#   'NEW YORK',
#   'Unenclosed',
#   680,
#   21,
#   62,
#   '12/15/2020'],
#  ['0959237-DCA',
#   'Inactive',
#   'MOHECO, INC.',
#   'ASTORIA',
#   'Unenclosed',
#   289,
#   11,
#   26,
#   '03/31/2020'],
#  ['2087605-DCA',
#   'Active',
#   'CABRERA ARGUDO CORP',
#   'NEW YORK',
#   'Unenclosed',
#   402,
#   24,
#   48,
#   '04/15/2021'],
#  ['1470950-DCA',
#   'Active',
#   'HAVATEQUILA RESTAURANT PARTNERS, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   1253,
#   19,
#   38,
#   '07/31/2020'],
#  ['2038092-DCA',
#   'Inactive',
#   'AMITY HALL UPTOWN INC.',
#   'NEW YORK',
#   'Unenclosed',
#   265,
#   12,
#   24,
#   '12/15/2020'],
#  ['0895586-DCA',
#   'Active',
#   'M.B.R.P. REST. INC.',
#   'NEW YORK',
#   'Enclosed',
#   265,
#   12,
#   25,
#   '05/15/2021'],
#  ['2050853-DCA',
#   'Active',
#   'WESTSIDE DONUT AMSTERDAM VENTURES LLC',
#   'NEW YORK',
#   'Unenclosed',
#   152,
#   4,
#   8,
#   '09/15/2021'],
#  ['2088549-DCA',
#   'Active',
#   'LE2 LLC',
#   'NEW YORK',
#   'Unenclosed',
#   177,
#   6,
#   12,
#   '09/15/2021'],
#  ['1427814-DCA',
#   'Inactive',
#   '42-02 TAVERN INC.',
#   'ASTORIA',
#   'Unenclosed',
#   353,
#   17,
#   34,
#   '12/15/2020'],
#  ['2038120-DCA',
#   'Inactive',
#   "LUKE'S LOUNGE INC",
#   'BRONX',
#   'Unenclosed',
#   83,
#   2,
#   8,
#   '12/15/2020'],
#  ['2026147-DCA',
#   'Active',
#   'MAHAPOCHANAHPHAN INC',
#   'ASTORIA',
#   'Unenclosed',
#   518,
#   18,
#   36,
#   '04/15/2021'],
#  ['1418144-DCA',
#   'Inactive',
#   'SERAFINA 77 WEST , LLC',
#   'NEW YORK',
#   'Unenclosed',
#   667,
#   38,
#   76,
#   '12/15/2020'],
#  ['1246104-DCA',
#   'Inactive',
#   'DLS CHICKEN CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   305,
#   8,
#   32,
#   '03/26/2020'],
#  ['1138459-DCA',
#   'Active',
#   'MA. VI. DO. REST. INC.',
#   'NEW YORK',
#   'Unenclosed',
#   688,
#   32,
#   60,
#   '09/15/2021'],
#  ['1282774-DCA',
#   'Inactive',
#   '201 REST. 95TH ST. CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   146,
#   8,
#   16,
#   '12/15/2020'],
#  ['2078104-DCA',
#   'Inactive',
#   '425 GRAHAM RESTAURANT INC',
#   'BROOKLYN',
#   'Unenclosed',
#   120,
#   7,
#   14,
#   '12/15/2020'],
#  ['2024028-DCA',
#   'Inactive',
#   'CROWN ALLEY LLC',
#   'NEW YORK',
#   'Unenclosed',
#   220,
#   11,
#   22,
#   '12/15/2020'],
#  ['1221449-DCA',
#   'Inactive',
#   "PEPE'S REST. GROUP LLC",
#   'NEW YORK',
#   'Unenclosed',
#   33,
#   2,
#   4,
#   '09/15/2020'],
#  ['0945762-DCA',
#   'Inactive',
#   '136 WEST BROADWAY, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   96,
#   6,
#   12,
#   '04/24/2020'],
#  ['1383186-DCA',
#   'Inactive',
#   'CHERRY LANE, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   149,
#   7,
#   16,
#   '09/11/2020'],
#  ['1458966-DCA',
#   'Inactive',
#   'PLAN A GROUP, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   134,
#   4,
#   16,
#   '04/11/2020'],
#  ['2074652-DCA',
#   'Inactive',
#   'EL ENCANTO DE LOLA 2 LLC',
#   'NEW YORK',
#   'Unenclosed',
#   351,
#   20,
#   40,
#   '12/15/2020'],
#  ['2091250-DCA',
#   'Active',
#   'HHC 33 PECK SLIP HOLDINGS LLC',
#   'NEW YORK',
#   'Unenclosed',
#   505,
#   7,
#   14,
#   '12/15/2021'],
#  ['2010250-DCA',
#   'Active',
#   'SEVEN A CAFE INC.',
#   'NEW YORK',
#   'Unenclosed',
#   229,
#   10,
#   20,
#   '04/09/2020'],
#  ['2025571-DCA',
#   'Active',
#   'STONEFRUIT INC.',
#   'BROOKLYN',
#   'Unenclosed',
#   121,
#   6,
#   12,
#   '04/15/2021'],
#  ['1452982-DCA',
#   'Inactive',
#   'SOH PEACE, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   108,
#   7,
#   14,
#   '03/12/2020'],
#  ['2071248-DCA',
#   'Inactive',
#   'NATURAL CROP INC.',
#   'BROOKLYN',
#   'Unenclosed',
#   127,
#   8,
#   32,
#   '12/15/2020'],
#  ['2053443-DCA',
#   'Active',
#   '910 SEVENTH  AVE REST LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   132,
#   4,
#   16,
#   '09/15/2021'],
#  ['1468273-DCA',
#   'Active',
#   'DE ARMAS ENTERPRISES CORP.',
#   'NEW YORK',
#   'Small Unenclosed',
#   132,
#   2,
#   8,
#   '09/15/2021'],
#  ['1396587-DCA',
#   'Active',
#   'FLAGSHIP S B AMSTERDAM NY, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   198,
#   11,
#   22,
#   '04/15/2021'],
#  ['2078117-DCA',
#   'Inactive',
#   'ESQEV LLC',
#   'NEW YORK',
#   'Unenclosed',
#   231,
#   8,
#   18,
#   '08/15/2020'],
#  ['2091718-DCA',
#   'Active',
#   'GREENE STREET SUPERFOODS LLC',
#   'NEW YORK',
#   'Unenclosed',
#   92,
#   6,
#   12,
#   '12/15/2021'],
#  ['1348205-DCA',
#   'Active',
#   'THIRD AVE CAFE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   540,
#   19,
#   38,
#   '04/15/2021'],
#  ['1451850-DCA',
#   'Inactive',
#   'VEM GROUP CORP.',
#   'ASTORIA',
#   'Unenclosed',
#   278,
#   16,
#   32,
#   '12/15/2020'],
#  ['2034028-DCA',
#   'Inactive',
#   'GG33 CORP',
#   'ASTORIA',
#   'Unenclosed',
#   446,
#   16,
#   32,
#   '12/15/2020'],
#  ['2051498-DCA',
#   'Inactive',
#   'SWEETGREEN NEW YORK LLC',
#   'NEW YORK',
#   'Unenclosed',
#   114,
#   4,
#   10,
#   '03/26/2020'],
#  ['1159625-DCA',
#   'Active',
#   "ELI'S MANHATTAN WAREHOUSE, INC.",
#   'NEW YORK',
#   'Unenclosed',
#   87,
#   5,
#   20,
#   '04/15/2022'],
#  ['2021587-DCA',
#   'Active',
#   'PQ EAST 77TH INC',
#   'NEW YORK',
#   'Unenclosed',
#   225,
#   11,
#   25,
#   '04/15/2021'],
#  ['2018723-DCA',
#   'Active',
#   'MORNINGSIDE TERRACE CORP',
#   'NEW YORK',
#   'Unenclosed',
#   105,
#   6,
#   12,
#   '09/15/2021'],
#  ['1425933-DCA',
#   'Inactive',
#   'CREDENCE LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   380,
#   16,
#   32,
#   '09/15/2020'],
#  ['2050152-DCA',
#   'Inactive',
#   'PARIS CAFE LLC',
#   'NEW YORK',
#   'Regular Unenclosed/Small Unenclosed',
#   328,
#   13,
#   26,
#   '09/15/2020'],
#  ['2023072-DCA',
#   'Inactive',
#   'SUPERPIZZA01 CORP',
#   'BROOKLYN',
#   'Unenclosed',
#   49,
#   4,
#   8,
#   '02/22/2020'],
#  ['2084461-DCA',
#   'Active',
#   'BOYYTHAI CORP',
#   'NEW YORK',
#   'Unenclosed',
#   285,
#   9,
#   18,
#   '04/15/2021'],
#  ['1457455-DCA',
#   'Active',
#   'MEDI WINEBAR, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   135,
#   3,
#   12,
#   '04/15/2021'],
#  ['0976266-DCA',
#   'Active',
#   'CAFE FOCACCIA, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   290,
#   9,
#   18,
#   '09/15/2021'],
#  ['2051463-DCA',
#   'Inactive',
#   'AROKA HOSPITALITY LLC',
#   'NEW YORK',
#   'Unenclosed',
#   150,
#   6,
#   12,
#   '03/25/2020'],
#  ['1426393-DCA',
#   'Inactive',
#   '343 BROOME STREET RESTAURANT INC',
#   'NEW YORK',
#   'Unenclosed',
#   132,
#   6,
#   18,
#   '09/15/2020'],
#  ['1314421-DCA',
#   'Active',
#   '2896 BROADWAY FOOD SERVICE INC.',
#   'NEW YORK',
#   'Unenclosed',
#   500,
#   23,
#   60,
#   '04/15/2021'],
#  ['2037230-DCA',
#   'Inactive',
#   'THE WREN NEW YORK LLC',
#   'NEW YORK',
#   'Unenclosed',
#   184,
#   5,
#   14,
#   '12/15/2020'],
#  ['2074710-DCA',
#   'Inactive',
#   'LOW OVERRUN LLC',
#   'NEW YORK',
#   'Unenclosed',
#   408,
#   16,
#   32,
#   '04/02/2020'],
#  ['2071749-DCA',
#   'Inactive',
#   "FRIJOLITO'S RESTAURANT CORP",
#   'NEW YORK',
#   'Unenclosed',
#   135,
#   7,
#   14,
#   '09/15/2020'],
#  ['1028755-DCA',
#   'Active',
#   '1236 SECOND AVENUE REST. CORP.',
#   'NEW YORK',
#   'Enclosed',
#   645,
#   23,
#   56,
#   '05/15/2021'],
#  ['2049157-DCA',
#   'Active',
#   'WINSOME FOODS, LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   227,
#   12,
#   24,
#   '04/15/2021'],
#  ['1139678-DCA',
#   'Inactive',
#   "THE ORIGINAL VINCENT'S, ESTABLISHED 1904 INC.",
#   'NEW YORK',
#   'Unenclosed',
#   355,
#   9,
#   18,
#   '08/03/2020'],
#  ['2078572-DCA',
#   'Inactive',
#   'DEAN & DELUCA SMALL FORMAT LQ, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   450,
#   12,
#   36,
#   '12/15/2020'],
#  ['1197788-DCA',
#   'Active',
#   'L.L.B., INC.',
#   'NEW YORK',
#   'Small Unenclosed',
#   65,
#   2,
#   4,
#   '12/15/2021'],
#  ['2086173-DCA',
#   'Active',
#   'RBO ON 2ND AVE CORP',
#   'NEW YORK',
#   'Unenclosed',
#   142,
#   8,
#   16,
#   '09/15/2021'],
#  ['2042124-DCA',
#   'Inactive',
#   'ST. GEORGE HOLDING, CORP',
#   'ASTORIA',
#   'Unenclosed',
#   238,
#   5,
#   20,
#   '12/15/2020'],
#  ['2021276-DCA',
#   'Active',
#   'CACTUS PEAR LLC',
#   'NEW YORK',
#   'Unenclosed',
#   474,
#   18,
#   54,
#   '09/15/2021'],
#  ['1385967-DCA',
#   'Inactive',
#   'TAPPO, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   140,
#   5,
#   10,
#   '08/29/2020'],
#  ['1365397-DCA',
#   'Active',
#   'MVNBC CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   373,
#   15,
#   30,
#   '04/15/2021'],
#  ['1387916-DCA',
#   'Active',
#   '187 RESTAURANT CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   181,
#   4,
#   16,
#   '09/15/2021'],
#  ['2010852-DCA',
#   'Inactive',
#   'GREENWOOD LAKE GROUP LLC',
#   'NEW YORK',
#   'Unenclosed',
#   280,
#   6,
#   32,
#   '12/15/2020'],
#  ['2071752-DCA',
#   'Inactive',
#   'ITALIENNE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   241,
#   7,
#   14,
#   '12/15/2020'],
#  ['2025569-DCA',
#   'Active',
#   'JL SOLO INC',
#   'NEW YORK',
#   'Unenclosed',
#   138,
#   6,
#   15,
#   '09/15/2021'],
#  ['1463183-DCA',
#   'Inactive',
#   'COOPER SQUARE 267 LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   641,
#   30,
#   68,
#   '12/15/2019'],
#  ['2011212-DCA',
#   'Inactive',
#   'HEARTH RESTAURANT INVESTORS, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   244,
#   9,
#   18,
#   '12/15/2020'],
#  ['1353701-DCA',
#   'Active',
#   '94 CORNER CAFE CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   177,
#   4,
#   16,
#   '04/15/2022'],
#  ['1315889-DCA',
#   'Active',
#   'S.G.M.G. CORP.',
#   'BRONX',
#   'Unenclosed',
#   349,
#   12,
#   24,
#   '09/15/2021'],
#  ['2023397-DCA',
#   'Active',
#   'BAR BERTRAND LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   177,
#   8,
#   16,
#   '04/15/2021'],
#  ['0670525-DCA',
#   'Active',
#   'CALIENTE CAB REST. CO., INC.',
#   'NEW YORK',
#   'Unenclosed',
#   752,
#   42,
#   84,
#   '04/15/2021'],
#  ['2053891-DCA',
#   'Active',
#   'TUMMA KHAKUEN INC',
#   'NEW YORK',
#   'Unenclosed',
#   374,
#   19,
#   38,
#   '04/15/2021'],
#  ['1172166-DCA',
#   'Inactive',
#   'POSTO INC.',
#   'NEW YORK',
#   'Unenclosed',
#   273,
#   10,
#   20,
#   '07/01/2020'],
#  ['2074071-DCA',
#   'Inactive',
#   'VIETNAAM II, INC',
#   'NEW YORK',
#   'Unenclosed',
#   312,
#   19,
#   40,
#   '09/05/2020'],
#  ['2024384-DCA',
#   'Active',
#   '2122 BEEKMAN BAR LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   228,
#   20,
#   40,
#   '12/15/2021'],
#  ['1415817-DCA',
#   'Active',
#   'SPRING NATURAL CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   233,
#   10,
#   20,
#   '04/15/2021'],
#  ['1282786-DCA',
#   'Active',
#   "BIG DADDY'S II LLC",
#   'NEW YORK',
#   'Unenclosed',
#   301,
#   16,
#   32,
#   '09/15/2021'],
#  ['2045882-DCA',
#   'Inactive',
#   '75TH & 3RD CORP.',
#   'NEW YORK',
#   'Enclosed',
#   504,
#   13,
#   41,
#   '04/18/2020'],
#  ['2086168-DCA',
#   'Active',
#   'BETTOLA NYC CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   156,
#   13,
#   26,
#   '12/15/2021'],
#  ['1308999-DCA',
#   'Inactive',
#   'DESMO 916 CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   162,
#   6,
#   20,
#   '06/11/2020'],
#  ['1190138-DCA',
#   'Active',
#   'PMC CORP.',
#   'NEW YORK',
#   'Enclosed',
#   336,
#   8,
#   18,
#   '05/15/2022'],
#  ['1309076-DCA',
#   'Active',
#   '18 BEDFORD AVE., LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   319,
#   15,
#   30,
#   '09/15/2021'],
#  ['1120483-DCA',
#   'Inactive',
#   '1 & 3 ON 5TH CORP.',
#   'BROOKLYN',
#   'Unenclosed',
#   266,
#   13,
#   26,
#   '07/14/2020'],
#  ['1469748-DCA',
#   'Inactive',
#   'GOOD VISION TASTE INC.',
#   'BROOKLYN',
#   'Unenclosed',
#   623,
#   32,
#   64,
#   '08/06/2020'],
#  ['1469257-DCA',
#   'Inactive',
#   'BRASSERIE COGNAC EAST CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   260,
#   9,
#   22,
#   '03/19/2020'],
#  ['1145512-DCA',
#   'Inactive',
#   'COFFEE PLACE CORP.',
#   'BROOKLYN',
#   'Unenclosed',
#   405,
#   11,
#   22,
#   '04/13/2020'],
#  ['2020261-DCA',
#   'Active',
#   'BROOKLYN ACQUISITION HOLDING LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   783,
#   41,
#   82,
#   '04/15/2021'],
#  ['1311123-DCA',
#   'Active',
#   'MAZ MEZCAL INC.',
#   'NEW YORK',
#   'Small Unenclosed',
#   208,
#   6,
#   24,
#   '09/15/2021'],
#  ['1385722-DCA',
#   'Inactive',
#   '568 5TH BROOKLYN LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   324,
#   10,
#   20,
#   '04/05/2020'],
#  ['1445109-DCA',
#   'Active',
#   'VICTORY SWEET SHOP, LTD.',
#   'ASTORIA',
#   'Unenclosed',
#   195,
#   6,
#   18,
#   '09/15/2021'],
#  ['1249567-DCA',
#   'Active',
#   'BANCONE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   369,
#   10,
#   30,
#   '04/15/2021'],
#  ['1319263-DCA',
#   'Active',
#   'GREENWICH HOTEL RESTAURANT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   570,
#   19,
#   38,
#   '09/15/2021'],
#  ['0949447-DCA',
#   'Active',
#   '164 MULBERRY ST. CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   113,
#   4,
#   8,
#   '04/15/2021'],
#  ['2041384-DCA',
#   'Inactive',
#   'JOSAN & JOSAN, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   256,
#   10,
#   30,
#   '12/15/2020'],
#  ['1392078-DCA',
#   'Inactive',
#   '72ND & COLUMBUS RESTAURANT LLC',
#   'NEW YORK',
#   'Enclosed',
#   416,
#   16,
#   34,
#   '02/22/2020'],
#  ['2078103-DCA',
#   'Inactive',
#   'ANTIOCHIA GRILL INC',
#   'FOREST HILLS',
#   'Unenclosed',
#   288,
#   12,
#   24,
#   '09/15/2020'],
#  ['2051494-DCA',
#   'Inactive',
#   'SAUCE MANAGEMENT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   378,
#   17,
#   34,
#   '08/03/2020'],
#  ['2038114-DCA',
#   'Inactive',
#   'FOOTPRINTS CAFE INC.',
#   'BROOKLYN',
#   'Unenclosed',
#   184,
#   8,
#   16,
#   '12/15/2020'],
#  ['1252836-DCA',
#   'Inactive',
#   'RIZ BAGEL INC.',
#   'WOODSIDE',
#   'Enclosed',
#   306,
#   8,
#   23,
#   '09/16/2019'],
#  ['2077342-DCA',
#   'Inactive',
#   'WOLFE L.I.C INC',
#   'ASTORIA',
#   'Unenclosed',
#   127,
#   5,
#   10,
#   '12/15/2020'],
#  ['2050841-DCA',
#   'Active',
#   '34-02 Broadway Tavern, Inc.',
#   'ASTORIA',
#   'Unenclosed',
#   435,
#   14,
#   28,
#   '04/15/2021'],
#  ['2049843-DCA',
#   'Active',
#   'ROSSINI, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   440,
#   18,
#   52,
#   '09/15/2021'],
#  ['2023069-DCA',
#   'Active',
#   'LULA ENTERPRISES, LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   523,
#   30,
#   64,
#   '09/15/2021'],
#  ['2018163-DCA',
#   'Active',
#   'SECOND STREET RESTAURANT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   119,
#   16,
#   32,
#   '09/15/2021'],
#  ['2027041-DCA',
#   'Active',
#   'Masa 8 LLC',
#   'NEW YORK',
#   'Unenclosed',
#   427,
#   13,
#   38,
#   '04/15/2021'],
#  ['1145629-DCA',
#   'Active',
#   'GRAND ENDEAVORS, INC.',
#   'BROOKLYN',
#   'Unenclosed',
#   264,
#   5,
#   20,
#   '09/15/2021'],
#  ['1193339-DCA',
#   'Inactive',
#   'EISEN & SON, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   253,
#   8,
#   25,
#   '12/31/2019'],
#  ['1316170-DCA',
#   'Inactive',
#   'MARCO POLO TAKE OUT LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   99,
#   4,
#   8,
#   '09/05/2020'],
#  ['2057458-DCA',
#   'Inactive',
#   'ARTICHOKE BUSHWICK LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   216,
#   10,
#   20,
#   '04/30/2020'],
#  ['0890521-DCA',
#   'Active',
#   '200 EAST 81ST RESTAURANT CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   253,
#   16,
#   32,
#   '04/15/2021'],
#  ['2041109-DCA',
#   'Inactive',
#   'MOSHGAB CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   70,
#   5,
#   10,
#   '09/15/2020'],
#  ['1224204-DCA',
#   'Inactive',
#   '156 TENTH AVENUE RESTAURANT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   506,
#   22,
#   44,
#   '12/15/2020'],
#  ['2035053-DCA',
#   'Inactive',
#   'SPRING SOHO INC',
#   'NEW YORK',
#   'Regular Unenclosed/Small Unenclosed',
#   301,
#   11,
#   22,
#   '09/15/2020'],
#  ['2004733-DCA',
#   'Inactive',
#   'MAMA BAR LLC',
#   'NEW YORK',
#   'Unenclosed',
#   201,
#   10,
#   20,
#   '09/15/2020'],
#  ['2078944-DCA',
#   'Inactive',
# ...
#   '268 WEST BROADWAY, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   320,
#   8,
#   16,
#   '09/15/2020'],
#  ['2038463-DCA',
#   'Inactive',
#   'SINGLECUT BEERSMITHS LLC',
#   'ASTORIA',
#   'Unenclosed',
#   117,
#   4,
#   16,
#   '09/15/2020'],
#  ['1159248-DCA',
#   'Inactive',
#   '675 HUDSON VAULT, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   1300,
#   48,
#   135,
#   '12/15/2020'],
#  ['1103083-DCA',
#   'Active',
#   'GROUBEN FOOD CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   125,
#   4,
#   8,
#   '09/15/2021'],
#  ['2021604-DCA',
#   'Active',
#   'CONCORD HILL INC',
#   'BROOKLYN',
#   'Unenclosed',
#   127,
#   7,
#   16,
#   '12/15/2021'],
#  ['1453505-DCA',
#   'Active',
#   '92ND AND 3RD REST CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   468,
#   35,
#   70,
#   '04/15/2021'],
#  ['1472635-DCA',
#   'Active',
#   'MEXICAN FESTIVAL NYC LLC',
#   'NEW YORK',
#   'Enclosed',
#   600,
#   19,
#   56,
#   '05/15/2021'],
#  ['2038130-DCA',
#   'Inactive',
#   'TOURBILLON 45 LLC',
#   'NEW YORK',
#   'Unenclosed',
#   163,
#   5,
#   20,
#   '12/15/2020'],
#  ['2018721-DCA',
#   'Active',
#   'CLOVE INDIAN RESTAURANT INC.',
#   'NEW YORK',
#   'Unenclosed',
#   187,
#   12,
#   24,
#   '04/15/2021'],
#  ['1346238-DCA',
#   'Active',
#   'HURRICANE STRAUSS, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   92,
#   6,
#   12,
#   '12/15/2021'],
#  ['1141700-DCA',
#   'Active',
#   '23RD & 9TH RESTAURANT CORP.',
#   'NEW YORK',
#   'Enclosed',
#   692,
#   40,
#   80,
#   '05/15/2021'],
#  ['2088885-DCA',
#   'Active',
#   'PEANUT FACTORY LLC',
#   'NEW YORK',
#   'Unenclosed',
#   120,
#   6,
#   12,
#   '04/15/2021'],
#  ['0987452-DCA',
#   'Inactive',
#   'UKATOSH CORPORATION',
#   'ASTORIA',
#   'Enclosed',
#   289,
#   7,
#   14,
#   '05/17/2020'],
#  ['1338890-DCA',
#   'Inactive',
#   'TUTTO BENE RESTAURANT INC.',
#   'NEW YORK',
#   'Unenclosed',
#   126,
#   6,
#   12,
#   '06/05/2020'],
#  ['2070372-DCA',
#   'Inactive',
#   'SPIEGEL INC',
#   'NEW YORK',
#   'Unenclosed',
#   168,
#   7,
#   14,
#   '12/15/2020'],
#  ['1102989-DCA',
#   'Inactive',
#   'ZUMSCHNEIDER CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   532,
#   29,
#   60,
#   '09/15/2020'],
#  ['2093559-DCA',
#   'Active',
#   'CASA AZUL. INC',
#   'BROOKLYN',
#   'Unenclosed',
#   296,
#   9,
#   18,
#   '09/15/2022'],
#  ['1424846-DCA',
#   'Inactive',
#   'SHELBURNE BAR AND GRILL, INC.',
#   'NEW YORK',
#   'Small Unenclosed',
#   192,
#   4,
#   16,
#   '09/15/2020'],
#  ['2071246-DCA',
#   'Inactive',
#   'JOANNIDES GROUP LLC',
#   'ASTORIA',
#   'Unenclosed',
#   473,
#   16,
#   32,
#   '09/15/2020'],
#  ['2036313-DCA',
#   'Inactive',
#   '568 AMSTERDAM LLC',
#   'NEW YORK',
#   'Unenclosed',
#   180,
#   10,
#   20,
#   '07/14/2020'],
#  ['1331625-DCA',
#   'Active',
#   'JEMANYA CORP.',
#   'BROOKLYN',
#   'Unenclosed',
#   168,
#   9,
#   18,
#   '04/15/2021'],
#  ['2086165-DCA',
#   'Active',
#   'ABA TURKISH RESTAURANT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   164,
#   8,
#   16,
#   '04/15/2021'],
#  ['2070812-DCA',
#   'Inactive',
#   'DENIS AYDA LLC',
#   'ASTORIA',
#   'Unenclosed',
#   586,
#   30,
#   60,
#   '12/15/2020'],
#  ['2086797-DCA',
#   'Inactive',
#   'TABLE 20 LLC',
#   'NEW YORK',
#   'Unenclosed',
#   482,
#   25,
#   52,
#   '09/15/2020'],
#  ['2086160-DCA',
#   'Active',
#   '217 W85 LLC',
#   'NEW YORK',
#   'Unenclosed',
#   178,
#   10,
#   20,
#   '12/15/2021'],
#  ['1227042-DCA',
#   'Inactive',
#   '114 KENMARE ASSOCIATES, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   337,
#   8,
#   26,
#   '12/15/2020'],
#  ['1384218-DCA',
#   'Active',
#   'VINO POSTO CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   92,
#   5,
#   11,
#   '12/15/2021'],
#  ['1420950-DCA',
#   'Active',
#   'SNOWDAY LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   236,
#   10,
#   20,
#   '12/15/2020'],
#  ['2075843-DCA',
#   'Inactive',
#   'ALADDIN AND PRINCESS ZALABIA INC',
#   'ASTORIA',
#   'Unenclosed',
#   306,
#   10,
#   30,
#   '09/15/2020'],
#  ['2086166-DCA',
#   'Active',
#   'Barrel 1005 Corp',
#   'NEW YORK',
#   'Unenclosed',
#   289,
#   16,
#   32,
#   '09/15/2021'],
#  ['1281431-DCA',
#   'Inactive',
#   'BEN TAS CORP.',
#   'ASTORIA',
#   'Unenclosed',
#   185,
#   4,
#   12,
#   '03/10/2020'],
#  ['2070370-DCA',
#   'Inactive',
#   'MICHEL GE INC',
#   'NEW YORK',
#   'Unenclosed',
#   73,
#   4,
#   8,
#   '12/15/2020'],
#  ['1283643-DCA',
#   'Inactive',
#   'JPS VENTURES INC.',
#   'NEW YORK',
#   'Enclosed',
#   224,
#   5,
#   16,
#   '03/17/2020'],
#  ['2091638-DCA',
#   'Active',
#   '225 WEST BROADWAY CORP',
#   'NEW YORK',
#   'Unenclosed',
#   67,
#   3,
#   6,
#   '12/15/2021'],
#  ['2066984-DCA',
#   'Inactive',
#   '190 SEVENTH AVENUE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   263,
#   16,
#   32,
#   '12/15/2020'],
#  ['2049839-DCA',
#   'Active',
#   'ATLA LAFAYETTE LLC',
#   'NEW YORK',
#   'Unenclosed',
#   407,
#   13,
#   38,
#   '09/15/2021'],
#  ['2011932-DCA',
#   'Inactive',
#   'BEACWAY OPERATING, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   461,
#   8,
#   32,
#   '12/15/2020'],
#  ['2072346-DCA',
#   'Inactive',
#   'UPNORTH BURGER LLC',
#   'NEW YORK',
#   'Unenclosed',
#   161,
#   10,
#   18,
#   '09/15/2020'],
#  ['2008446-DCA',
#   'Inactive',
#   'TABLE 87 GOWANUS NYC LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   328,
#   6,
#   24,
#   '09/15/2020'],
#  ['2055674-DCA',
#   'Inactive',
#   'BALCONY CAFE INC.',
#   'NEW YORK',
#   'Unenclosed',
#   237,
#   13,
#   26,
#   '03/28/2020'],
#  ['2007743-DCA',
#   'Inactive',
#   'NYC BAGELS & COFFEE SHOP INC',
#   'ASTORIA',
#   'Unenclosed',
#   189,
#   9,
#   18,
#   '09/15/2020'],
#  ['2015728-DCA',
#   'Inactive',
#   'ALIAGED DINING INC',
#   'FOREST HILLS',
#   'Unenclosed',
#   278,
#   13,
#   28,
#   '04/05/2020'],
#  ['2060235-DCA',
#   'Inactive',
#   'HASHEM MELECH, INC',
#   'FLUSHING',
#   'Enclosed',
#   508,
#   12,
#   48,
#   '07/01/2020'],
#  ['2050840-DCA',
#   'Inactive',
#   '1483 FIRST AVENUE RESTAURANT INC.',
#   'NEW YORK',
#   'Unenclosed',
#   72,
#   8,
#   16,
#   '08/29/2020'],
#  ['2041410-DCA',
#   'Inactive',
#   'NEW YORK BURGER 10th AVE INC.',
#   'NEW YORK',
#   'Enclosed',
#   762,
#   25,
#   54,
#   '11/15/2020'],
#  ['2038098-DCA',
#   'Inactive',
#   'CAMPANIA FELIX LLC',
#   'NEW YORK',
#   'Enclosed',
#   345,
#   10,
#   25,
#   '05/20/2020'],
#  ['1458267-DCA',
#   'Active',
#   'PIACERE ENTERPRISES LLC',
#   'NEW YORK',
#   'Unenclosed',
#   170,
#   8,
#   24,
#   '04/15/2021'],
#  ['2024806-DCA',
#   'Active',
#   'STARLITE WALKER LLC',
#   'BROOKLYN',
#   'Small Unenclosed',
#   175,
#   7,
#   14,
#   '09/15/2021'],
#  ['2023070-DCA',
#   'Active',
#   'NISIDA LLC',
#   'NEW YORK',
#   'Unenclosed',
#   286,
#   8,
#   16,
#   '12/15/2021'],
#  ['2006083-DCA',
#   'Inactive',
#   'OWM VERNON LLC',
#   'LONG ISLAND CITY',
#   'Regular Unenclosed/Small Unenclosed',
#   294,
#   10,
#   20,
#   '09/15/2020'],
#  ['2038808-DCA',
#   'Inactive',
#   'IHI-NY LLC',
#   'NEW YORK',
#   'Unenclosed',
#   189,
#   4,
#   16,
#   '12/15/2020'],
#  ['2011643-DCA',
#   'Inactive',
#   '26TH STREET RESTAURANT, LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   100,
#   3,
#   6,
#   '09/15/2020'],
#  ['1161434-DCA',
#   'Inactive',
#   'CARMINE RESTAURANT, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   170,
#   9,
#   18,
#   '12/15/2020'],
#  ['2072108-DCA',
#   'Inactive',
#   'TAPESTRY MANAGEMENT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   106,
#   5,
#   10,
#   '12/15/2020'],
#  ['', 'Inactive', "GEORGE'S SCC, INC.", 'BRONX', 'Enclosed', 511, 11, 44, ''],
#  ['1309603-DCA',
#   'Inactive',
#   'CHOW DOWN, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   275,
#   11,
#   22,
#   '04/22/2020'],
#  ['2074690-DCA',
#   'Inactive',
#   'ROJITA MANAGEMENT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   277,
#   7,
#   22,
#   '12/15/2020'],
#  ['1379700-DCA',
#   'Inactive',
#   'MY MOST FAVORITE 72ND ST. CORP.',
#   'NEW YORK',
#   'Enclosed',
#   350,
#   10,
#   27,
#   '05/30/2020'],
#  ['1284057-DCA',
#   'Active',
#   "MICKEY'S PLACE ON 43RD ST., LTD.",
#   'SUNNYSIDE',
#   'Unenclosed',
#   234,
#   16,
#   32,
#   '04/15/2021'],
#  ['2082428-DCA',
#   'Active',
#   "FRANK MAC'S PLACE, LLC",
#   'NEW YORK',
#   'Unenclosed',
#   178,
#   11,
#   24,
#   '12/15/2021'],
#  ['2074469-DCA',
#   'Inactive',
#   '181 LEXINGTON AVENUE BBQ LLC',
#   'NEW YORK',
#   'Unenclosed',
#   268,
#   11,
#   22,
#   '09/15/2020'],
#  ['2009249-DCA',
#   'Inactive',
#   'EAT MADISON LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   20,
#   1,
#   2,
#   '09/15/2020'],
#  ['1161856-DCA',
#   'Inactive',
#   'JEC II, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   655,
#   24,
#   58,
#   '09/15/2020'],
#  ['2077336-DCA',
#   'Inactive',
#   'IROM, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   172,
#   6,
#   12,
#   '09/15/2020'],
#  ['1422914-DCA',
#   'Inactive',
#   'TAJIN RESTAURANT CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   193,
#   10,
#   20,
#   '12/15/2020'],
#  ['2020258-DCA',
#   'Active',
#   '2850 BROADWAY REST ASSOCIATES LLC',
#   'NEW YORK',
#   'Unenclosed',
#   168,
#   9,
#   18,
#   '12/15/2021'],
#  ['2069713-DCA',
#   'Inactive',
#   'D&S DINING GROUP LLC',
#   'NEW YORK',
#   'Unenclosed',
#   188,
#   15,
#   30,
#   '09/15/2020'],
#  ['2050844-DCA',
#   'Inactive',
#   'CARRA LLC',
#   'NEW YORK',
#   'Unenclosed',
#   256,
#   11,
#   25,
#   '03/15/2020'],
#  ['2084772-DCA',
#   'Active',
#   'NONNA BEPPA SOHO LLC',
#   'NEW YORK',
#   'Unenclosed',
#   94,
#   2,
#   3,
#   '12/15/2021'],
#  ['1312044-DCA',
#   'Inactive',
#   'OSTERIA CASANO LLC',
#   'NEW YORK',
#   'Unenclosed',
#   320,
#   16,
#   31,
#   '03/25/2020'],
#  ['1258524-DCA',
#   'Active',
#   '88 2ND AVE. FOOD CORP.',
#   'NEW YORK',
#   'Enclosed',
#   364,
#   13,
#   26,
#   '03/25/2020'],
#  ['1343516-DCA',
#   'Inactive',
#   'CERELI INC.',
#   'NEW YORK',
#   'Unenclosed',
#   138,
#   7,
#   16,
#   '09/15/2020'],
#  ['1320701-DCA',
#   'Active',
#   '352 RESTAURANT CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   200,
#   6,
#   12,
#   '04/15/2021'],
#  ['1142288-DCA',
#   'Inactive',
#   'OLD HEIDELBERG CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   228,
#   12,
#   24,
#   '03/18/2020'],
#  ['1334619-DCA',
#   'Inactive',
#   'MADISON GLOBAL LLC',
#   'NEW YORK',
#   'Small Unenclosed',
#   126,
#   3,
#   12,
#   '03/15/2020'],
#  ['2007742-DCA',
#   'Inactive',
#   'NITEHAWK BROOKLYN LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   266,
#   14,
#   28,
#   '04/10/2020'],
#  ['0978961-DCA',
#   'Inactive',
#   'ST. JAMES ASSOCIATES, L.P.',
#   'NEW YORK',
#   'Enclosed',
#   334,
#   12,
#   24,
#   '03/05/2020'],
#  ['2021586-DCA',
#   'Active',
#   'YERINA RESTAURANT CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   94,
#   3,
#   8,
#   '09/15/2021'],
#  ['1110383-DCA',
#   'Inactive',
#   'ANOTHEROOM, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   140,
#   8,
#   16,
#   '04/15/2020'],
#  ['1381393-DCA',
#   'Inactive',
#   'ALA TURK INC',
#   'NEW YORK',
#   'Enclosed',
#   481,
#   12,
#   39,
#   '04/26/2020'],
#  ['1172157-DCA',
#   'Active',
#   'E. A. T. IS OWNED BY ELI ZABAR, INC.',
#   'NEW YORK',
#   'Small Unenclosed',
#   127,
#   6,
#   12,
#   '04/15/2022'],
#  ['1192416-DCA',
#   'Inactive',
#   'CIELI PARTNERS, L.P.',
#   'NEW YORK',
#   'Small Unenclosed',
#   268,
#   7,
#   28,
#   '06/30/2020'],
#  ['1000314-DCA',
#   'Inactive',
#   'BROADWAY DESSERTS, LTD.',
#   'NEW YORK',
#   'Unenclosed',
#   480,
#   21,
#   48,
#   '06/30/2020'],
#  ['2036874-DCA',
#   'Inactive',
#   'BROOKLYN THIN CRUST INC',
#   'BROOKLYN',
#   'Unenclosed',
#   153,
#   8,
#   18,
#   '12/15/2020'],
#  ['1392090-DCA',
#   'Active',
#   'IXHEL CORPORATION',
#   'NEW YORK',
#   'Enclosed',
#   285,
#   10,
#   28,
#   '05/15/2021'],
#  ['2024047-DCA',
#   'Active',
#   'SIXTH AVENUE RESTAURANT MANAGEMENT LLC',
#   'NEW YORK',
#   'Unenclosed',
#   420,
#   18,
#   36,
#   '04/15/2021'],
#  ['2026474-DCA',
#   'Inactive',
#   'TARENTUM LTD',
#   'NEW YORK',
#   'Unenclosed',
#   87,
#   3,
#   8,
#   '01/29/2020'],
#  ['2083468-DCA',
#   'Active',
#   '3706 THIRTY INC.',
#   'ASTORIA',
#   'Unenclosed',
#   112,
#   6,
#   12,
#   '12/15/2021'],
#  ['1418049-DCA',
#   'Inactive',
#   'MZ RESTAURANT GROUP LLC',
#   'ASTORIA',
#   'Unenclosed',
#   383,
#   9,
#   34,
#   '09/15/2020'],
#  ['0981250-DCA',
#   'Inactive',
#   'BSWR CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   139,
#   7,
#   16,
#   '12/15/2020'],
#  ['2092751-DCA',
#   'Active',
#   'PIATTO LLC',
#   'LONG ISLAND CITY',
#   'Unenclosed',
#   336,
#   9,
#   18,
#   '04/15/2021'],
#  ['2002605-DCA',
#   'Active',
#   'IL PORTO BRICK OVEN RISTORANTE LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   207,
#   8,
#   18,
#   '04/15/2021'],
#  ['2010360-DCA',
#   'Inactive',
#   'AK RESTAURANT GROUP LLC',
#   'ASTORIA',
#   'Unenclosed',
#   817,
#   20,
#   74,
#   '12/15/2020'],
#  ['1310240-DCA',
#   'Inactive',
#   '401 W 50 TAVERN INC.',
#   'NEW YORK',
#   'Small Unenclosed',
#   108,
#   6,
#   12,
#   '07/31/2020'],
#  ['2022425-DCA',
#   'Active',
#   'AFB LOUNGE, LLC',
#   'ASTORIA',
#   'Unenclosed',
#   85,
#   4,
#   16,
#   '04/15/2021'],
#  ['2093354-DCA',
#   'Active',
#   'DIG INN 412 GREENWICH STREET, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   178,
#   4,
#   8,
#   '12/15/2022'],
#  ['2056083-DCA',
#   'Inactive',
#   'TWO MELONS LLC',
#   'NEW YORK',
#   'Unenclosed',
#   168,
#   7,
#   14,
#   '09/15/2020'],
#  ['1191523-DCA',
#   'Active',
#   'SHIRT RESTAURANT CORP.',
#   'NEW YORK',
#   'Small Unenclosed',
#   83,
#   2,
#   8,
#   '09/15/2021'],
#  ['2032891-DCA',
#   'Inactive',
#   '86 SOUTH PORTLAND, LLC',
#   'BROOKLYN',
#   'Enclosed',
#   118,
#   7,
#   14,
#   '04/19/2020'],
#  ['2012539-DCA',
#   'Inactive',
#   'MANGOLICIOUS QUEENS BLVD LTD',
#   'FOREST HILLS',
#   'Unenclosed',
#   217,
#   6,
#   12,
#   '09/15/2020'],
#  ['1420358-DCA',
#   'Inactive',
#   '1431 FIRST AVENUE CORP.',
#   'NEW YORK',
#   'Unenclosed',
#   180,
#   6,
#   16,
#   '12/15/2020'],
#  ['1214833-DCA',
#   'Inactive',
#   'L.E. GLOBE, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   565,
#   18,
#   60,
#   '08/28/2020'],
#  ['2075352-DCA',
#   'Active',
#   'EASTSIDE BARKING DOG INC',
#   'NEW YORK',
#   'Unenclosed',
#   159,
#   6,
#   12,
#   '12/15/2021'],
#  ['2025209-DCA',
#   'Active',
#   'OSO HAMILTON HEIGHTS, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   180,
#   9,
#   18,
#   '09/15/2021'],
#  ['1424004-DCA',
#   'Inactive',
#   'COOLJAG CORP.',
#   'SUNNYSIDE',
#   'Small Unenclosed',
#   269,
#   10,
#   28,
#   '12/15/2020'],
#  ['1341402-DCA',
#   'Inactive',
#   'DONIZETTI LLC',
#   'NEW YORK',
#   'Unenclosed',
#   360,
#   12,
#   34,
#   '07/17/2020'],
#  ['1456771-DCA',
#   'Active',
#   'SIMMONS PROVISIONS OF NY, LLC',
#   'BROOKLYN',
#   'Unenclosed',
#   83,
#   2,
#   12,
#   '04/15/2021'],
#  ['2058401-DCA',
#   'Inactive',
#   '3713 RIVERDALE REST CORP.',
#   'BRONX',
#   'Unenclosed',
#   140,
#   9,
#   21,
#   '09/15/2020'],
#  ['2023879-DCA',
#   'Active',
#   'MARGHERITA CORPORATION',
#   'NEW YORK',
#   'Unenclosed',
#   84,
#   4,
#   8,
#   '09/15/2021'],
#  ['2032424-DCA',
#   'Inactive',
#   'TIG ASTORIA LLC',
#   'ASTORIA',
#   'Unenclosed',
#   116,
#   5,
#   10,
#   '12/15/2020'],
#  ['0940252-DCA',
#   'Inactive',
#   "CARMINE'S BROADWAY FEAST INC.",
#   'NEW YORK',
#   'Unenclosed',
#   264,
#   7,
#   22,
#   '04/03/2020'],
#  ['1177240-DCA',
#   'Inactive',
#   'GIGINO, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   115,
#   4,
#   10,
#   '12/15/2020'],
#  ['2025570-DCA',
#   'Active',
#   'JONILU, LLC.',
#   'NEW YORK',
#   'Unenclosed',
#   90,
#   7,
#   14,
#   '12/15/2021'],
#  ['1347910-DCA',
#   'Inactive',
#   'LEITRIM PUB INC.',
#   'NEW YORK',
#   'Unenclosed',
#   136,
#   8,
#   18,
#   '12/15/2020'],
#  ['2049840-DCA',
#   'Inactive',
#   'DESSERT PALACE BOSE INC',
#   'BROOKLYN',
#   'Unenclosed',
#   321,
#   11,
#   22,
#   '04/06/2020'],
#  ['2069714-DCA',
#   'Inactive',
#   'FIFTYTWO MERCHANTS LLC',
#   'NEW YORK',
#   'Unenclosed',
#   399,
#   20,
#   40,
#   '12/15/2020'],
#  ['0918521-DCA',
#   'Active',
#   'CABANA-70 ASSOCIATES, L.P.',
#   'FOREST HILLS',
#   'Unenclosed',
#   106,
#   4,
#   8,
#   '04/15/2021'],
#  ['1311871-DCA',
#   'Active',
#   '600 METROPOLITAN CORP.',
#   'BROOKLYN',
#   'Unenclosed',
#   184,
#   6,
#   18,
#   '04/15/2021'],
#  ['2082898-DCA',
#   'Active',
#   'ZIA MARIA LITTLE ITALY, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   75,
#   4,
#   8,
#   '12/15/2021'],
#  ['2035689-DCA',
#   'Inactive',
#   '1205 ON SURF CORP',
#   'BROOKLYN',
#   'Unenclosed',
#   224,
#   8,
#   24,
#   '09/15/2020'],
#  ['1072629-DCA',
#   'Inactive',
#   'LUNELLA RISTORANTE, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   110,
#   4,
#   8,
#   '04/04/2020'],
#  ['1248652-DCA',
#   'Inactive',
#   '22 EAST 54TH STREET RESTAURANT CORP.',
#   'NEW YORK',
#   'Small Unenclosed',
#   140,
#   5,
#   10,
#   '04/05/2020'],
#  ['2086764-DCA',
#   'Active',
#   '329 Hospitality Group LLC',
#   'NEW YORK',
#   'Unenclosed',
#   153,
#   10,
#   20,
#   '12/15/2021'],
#  ['1426466-DCA',
#   'Inactive',
#   'BRATS UND BIER, INC.',
#   'ASTORIA',
#   'Unenclosed',
#   324,
#   14,
#   28,
#   '09/15/2020'],
#  ['2077939-DCA',
#   'Inactive',
#   'CHELLA LUNA, INC',
#   'ASTORIA',
#   'Unenclosed',
#   390,
#   10,
#   30,
#   '03/25/2020'],
#  ['2082892-DCA',
#   'Active',
#   '1279 1ST AVENUE LLC',
#   'NEW YORK',
#   'Enclosed',
#   252,
#   11,
#   26,
#   '05/15/2021'],
#  ['1092103-DCA',
#   'Inactive',
#   'RAJMAR HOLDINGS, INC.',
#   'NEW YORK',
#   'Unenclosed',
#   80,
#   4,
#   8,
#   '07/26/2020'],
#  ['2007739-DCA',
#   'Inactive',
#   'NAUGHTY GULL, LLC',
#   'NEW YORK',
#   'Unenclosed',
#   147,
#   7,
#   17,
#   '09/15/2020'],
#  ['2073985-DCA',
#   'Inactive',
#   'GRACE BARZ LTD',
#   'ASTORIA',
#   'Enclosed',
#   720,
#   14,
#   56,
#   '02/12/2020'],
#  ['0804523-DCA',
#   'Inactive',
#   'TWO AND EIGHT GOURMET, LTD.',
#   'NEW YORK',
#   'Unenclosed',
#   535,
#   16,
#   32,
#   '09/15/2020'],
#  ['2042126-DCA',
#   'Inactive',
#   'THE ELEMENT RESTAURANT GROUP INC',
#   'NEW YORK',
#   'Unenclosed',
#   324,
#   11,
#   22,
#   '09/15/2020'],
#  ...]
